# %%
# This code uses the styleformer library to recreate the snopes dataset with formalized text. 
# Change the style_transfer_type integer to choose what kind of style transfer you wish
# 0 for informal to formal, 1 for formal to informal, 2 for active to passive, 3 for passive to active

style_transfer_type = 0

from google.colab import drive
import os
import sys
# !pip install transformers
drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive')
print(os.getcwd())
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 4.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 41.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 527 kB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 45.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 38.0 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5
# Mounted at /content/drive
# /content

# %%
# !pip install -r /content/drive/MyDrive/styleformer/requirements.txt
# Out:
# Obtaining styleformer from git+https://github.com/PrithivirajDamodaran/Styleformer.git#egg=styleformer (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 1))
#   Cloning https://github.com/PrithivirajDamodaran/Styleformer.git to ./src/styleformer
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Styleformer.git /content/src/styleformer
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (1.10.0+cu111)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.12.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.3 MB/s
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 6.4 MB/s
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.10.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.8.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2019.12.20)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.0.46)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.15.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149860 sha256=2852c593e235af6c65982b4bb9bc00565348262381bcd2136b10bb070718a1f3
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: sentencepiece, python-Levenshtein, fuzzywuzzy, styleformer
#   Running setup.py develop for styleformer
# Successfully installed fuzzywuzzy-0.18.0 python-Levenshtein-0.12.2 sentencepiece-0.1.96 styleformer-0.1

# %%
class Styleformer():

  def __init__(self,  style=0):
    from transformers import AutoTokenizer
    from transformers import AutoModelForSeq2SeqLM

    self.style = style
    self.adequacy = Adequacy()
    self.model_loaded = False

    if self.style == 0:
      self.ctf_tokenizer = AutoTokenizer.from_pretrained("prithivida/informal_to_formal_styletransfer")
      self.ctf_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/informal_to_formal_styletransfer")
      print("Casual to Formal model loaded...")
      self.model_loaded = True
    elif self.style == 1:
      self.ftc_tokenizer = AutoTokenizer.from_pretrained("prithivida/formal_to_informal_styletransfer")
      self.ftc_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/formal_to_informal_styletransfer")
      print("Formal to Casual model loaded...")
      self.model_loaded = True  
    elif self.style == 2:
      self.atp_tokenizer = AutoTokenizer.from_pretrained("prithivida/active_to_passive_styletransfer")
      self.atp_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/active_to_passive_styletransfer")
      print("Active to Passive model loaded...")  
      self.model_loaded = True
    elif self.style == 3:
      self.pta_tokenizer = AutoTokenizer.from_pretrained("prithivida/passive_to_active_styletransfer")
      self.pta_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/passive_to_active_styletransfer")
      print("Passive to Active model loaded...")        
      self.model_loaded = True
    else:
      print("Only CTF, FTC, ATP and PTA are supported in the pre-release...stay tuned")

  def transfer(self, input_sentence, inference_on=0, quality_filter=0.95, max_candidates=5):
      if self.model_loaded:
        if inference_on == 0:
          device = "cpu"
        elif inference_on == 1:
          device = "cuda:0"  
        else:  
          device = "cpu"
          print("Onnx + Quantisation is not supported in the pre-release...stay tuned.")

        if self.style == 0:
          output_sentence = self._casual_to_formal(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 1:
          output_sentence = self._formal_to_casual(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 2:
          output_sentence = self._active_to_passive(input_sentence, device)
          return output_sentence        
        elif self.style == 3:
          output_sentence = self._passive_to_active(input_sentence, device)
          return output_sentence           
      else:
        print("Models aren't loaded for this style, please use the right style during init")  


  def _formal_to_casual(self, input_sentence, device, quality_filter, max_candidates):
      ftc_prefix = "transfer Formal to Casual: "
      src_sentence = input_sentence
      input_sentence = ftc_prefix + input_sentence
      input_ids = self.ftc_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ftc_model = self.ftc_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ftc_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ftc_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _casual_to_formal(self, input_sentence, device, quality_filter, max_candidates):
      ctf_prefix = "transfer Casual to Formal: "
      src_sentence = input_sentence
      input_sentence = ctf_prefix + input_sentence
      input_ids = self.ctf_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ctf_model = self.ctf_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ctf_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ctf_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _active_to_passive(self, input_sentence, device):
      atp_prefix = "transfer Active to Passive: "
      src_sentence = input_sentence
      input_sentence = atp_prefix + input_sentence
      input_ids = self.atp_tokenizer.encode(input_sentence, return_tensors='pt')
      self.atp_model = self.atp_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.atp_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.atp_tokenizer.decode(preds[0], skip_special_tokens=True).strip()

  def _passive_to_active(self, input_sentence, device):
      pta_prefix = "transfer Passive to Active: "
      src_sentence = input_sentence
      input_sentence = pta_prefix + input_sentence
      input_ids = self.pta_tokenizer.encode(input_sentence, return_tensors='pt')
      self.pta_model = self.pta_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.pta_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.pta_tokenizer.decode(preds[0], skip_special_tokens=True).strip()      

    
class Adequacy():

  def __init__(self, model_tag='prithivida/parrot_adequacy_on_BART'):
    from transformers import AutoModelForSequenceClassification, AutoTokenizer
    self.nli_model = AutoModelForSequenceClassification.from_pretrained(model_tag)
    self.tokenizer = AutoTokenizer.from_pretrained(model_tag)
    
  def filter(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      top_adequacy_phrases = []
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
            top_adequacy_phrases.append(para_phrase)
      return top_adequacy_phrases

  def score(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      adequacy_scores = {}
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
          adequacy_scores[para_phrase] = adequacy_score
      return adequacy_scores

# %%
# !nvidia-smi
# Out:
# Mon Dec  6 04:27:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import os
import torch
import warnings
import transformers
import re
warnings.filterwarnings("ignore")

sf = Styleformer(style = style_transfer_type)

snes_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes.tsv"
snes_snippets_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes_snippets.tsv"

snes_col_list = ["claimID", "claim", "label", "claimURL", "reason", "categories", "speaker",
                 "checker", "tags", "articleTitle", "publishDate", "claimDate", "entities"]
df_snes = pd.read_csv(snes_path, sep='\t', names=snes_col_list, index_col=False)

snes_snippets_col_list = ["rank_position", "snippet1", "snippet2", "snippet3", "snippet4", 
                 "snippet5", "snippet6", "snippet7", "snippet8", "snippet9", "snippet10"]
df_snippets = pd.read_csv(snes_snippets_path, sep='\t', names=snes_snippets_col_list, index_col=False)
# Out:
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Casual to Formal model loaded...

# %%
df_snes
# Out:
#          claimID  ...           entities
# 0     snes-04484  ...           ['None']
# 1     snes-03162  ...           ['None']
# 2     snes-05436  ...           ['None']
# 3     snes-02901  ...       ['Kentucky']
# 4     snes-03347  ...           ['None']
# ...          ...  ...                ...
# 5064  snes-04959  ...           ['None']
# 5065  snes-01599  ...  ['United_States']
# 5066  snes-02900  ...           ['None']
# 5067  snes-03298  ...           ['None']
# 5068  snes-01833  ...           ['None']
#
# [5069 rows x 13 columns]

# %%
for index, row in df_snes.iterrows():
  full_target = ""  
  split_sentences = re.split(r'\.\.\.+', row['claim'])
  for split_sentence in split_sentences:
    target_sentence = sf.transfer(split_sentence, inference_on=1)
    print("-" *100)
    print("[Original] ", split_sentence)
    print("-" *100)
    if target_sentence is not None:
        print("[Formal] ",target_sentence)
        print()
        if full_target != "":
          full_target += " ... " + target_sentence
        else:
          full_target += target_sentence
    else:
        print("No good quality transfers available !")
  print("[Full Formal] ", full_target)
  print(str(index+1) + ": " + row['claim'])
  df_snes.at[index, 'claim'] = full_target
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------------------------------------------------------------------------
# [Original]  Rihanna was barred from entering Senegal on the grounds that she was suspected of being part of the Illuminati.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Rihanna was prohibited from entering Senegal because she was a suspected member of the Illuminati.
#
# [Full Formal]  Rihanna was prohibited from entering Senegal because she was a suspected member of the Illuminati.
# 4357: Rihanna was barred from entering Senegal on the grounds that she was suspected of being part of the Illuminati.
# ----------------------------------------------------------------------------------------------------
# [Original]  In July 2016, Massachusetts implemented a new ban on the sale of all semi-automatic rifles.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Massachusetts implemented a new ban on the sale of all semiautomatic rifles in July 2016.
#
# [Full Formal]  Massachusetts implemented a new ban on the sale of all semiautomatic rifles in July 2016.
# 4358: In July 2016, Massachusetts implemented a new ban on the sale of all semi-automatic rifles.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows Jay-Z and Beyonce holding their twin babies in June 2017.
# ----------------------------------------------------------------------------------------------------
# [Formal]  In a photograph, JayZ and Beyonce are holding their twin babies in June 2017.
#
# [Full Formal]  In a photograph, JayZ and Beyonce are holding their twin babies in June 2017.
# 4359: A photograph shows Jay-Z and Beyonce holding their twin babies in June 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  Facebook doesn't consider military emblems "appropriate" on their social network.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Facebook does not consider military emblems to be appropriate on its social network.
#
# [Full Formal]  Facebook does not consider military emblems to be appropriate on its social network.
# 4360: Facebook doesn't consider military emblems "appropriate" on their social network.
# ----------------------------------------------------------------------------------------------------
# [Original]  A woman murdered her college roommate over too many Candy Crush requests.
# ----------------------------------------------------------------------------------------------------
# [Formal]  A woman murdered her college roommate over too many candy crush requests.
#
# [Full Formal]  A woman murdered her college roommate over too many candy crush requests.
# 4361: A woman murdered her college roommate over too many Candy Crush requests.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did a Wendy’s Employee Admit to “Pooping” in Chili for Over 2 Years?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Did a Wendy's employee admit to pooping in Chili for more than two years?
#
# [Full Formal]  Did a Wendy's employee admit to pooping in Chili for more than two years?
# 4362: Did a Wendy’s Employee Admit to “Pooping” in Chili for Over 2 Years?
# ----------------------------------------------------------------------------------------------------
# [Original]  New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind of blood vessel in the hands and feet, ending the controversy over the disease’s cause and mechanism.
# ----------------------------------------------------------------------------------------------------
# [Formal]  New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind
#
# [Full Formal]  New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind
# 4363: New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind of blood vessel in the hands and feet, ending the controversy over the disease’s cause and mechanism.
# ----------------------------------------------------------------------------------------------------
# [Original]  Hillary Clinton's popular vote win in the presidential election came entirely from the state of California.
# ----------------------------------------------------------------------------------------------------
# [Formal]  

# ----------------------------------------------------------------------------------------------------
# [Formal]  The United States has the third highest rate of homicides worldwide.
#
# [Full Formal]  The United States has the third highest rate of homicides worldwide.
# 4388: The United States has the third-highest rate of homicides worldwide, but drops dramatically in the rankings if four major cities are excluded from the stats.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did a Tennessee Hardware Store Put Up a ‘No Gays Allowed’ Sign?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Did the Tennessee Hardware Store put up a sign saying no homosexuals allowed?
#
# [Full Formal]  Did the Tennessee Hardware Store put up a sign saying no homosexuals allowed?
# 4389: Did a Tennessee Hardware Store Put Up a ‘No Gays Allowed’ Sign?
# ----------------------------------------------------------------------------------------------------
# [Original]  Actor Harry Shearer announced in November 2017 that he was leaving 'The Simpsons.'
# ----------------------------------------------------------------------------------------------------
# [Formal]  The actor Harry Shearer announced in November 2017 that he was leaving The Simpsons.
#
# [Full Formal]  The actor Harry Shearer announced in November 2017 that he was leaving The Simpsons.
# 4390: Actor Harry Shearer announced in November 2017 that he was leaving 'The Simpsons.'
# ----------------------------------------------------------------------------------------------------
# [Original]  The U.S. federal government is enacting a nationwide minimum hunting age of twenty-one (or eighteen).
# ----------------------------------------------------------------------------------------------------
# [Formal]  The federal government of the United States is enacting a nationwide minimum hunting age of twenty one (or eighteen).
#
# [Full Formal]  The federal government of the United States is enacting a nationwide minimum hunting age of twenty one (or eighteen).
# 4391: The U.S. federal government is enacting a nationwide minimum hunting age of twenty-one (or eighteen).
# ----------------------------------------------------------------------------------------------------
# [Original]  Does This Trump-Loving Celebrity Want Critics to Move Out of the United States?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Does this affluent celebrity desire criticism to depart the United States?
#
# [Full Formal]  Does this affluent celebrity desire criticism to depart the United States?
# 4392: Does This Trump-Loving Celebrity Want Critics to Move Out of the United States?
# ----------------------------------------------------------------------------------------------------
# [Original]  Rihanna's Instagram message to followers to throw away the Snapchat app caused the company's share value to fall by hundreds of millions of dollars in one day.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Rihanna's Instagram message to followers caused the company's share value to fall by hundreds of millions of dollars in one day.
#
# [Full Formal]  Rihanna's Instagram message to followers caused the company's share value to fall by hundreds of millions of dollars in one day.
# 4393: Rihanna's Instagram message to followers to throw away the Snapchat app caused the company's share value to fall by hundreds of millions of dollars in one day.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows President Trump making a "fist-pumping" hand gesture at a memorial for 9/11 victims.
# ----------------------------------------------------------------------------------------------------
# [Formal]  A photograph depicts President Trump making a fist pumping hand gesture at a memorial for 9/11 victims.
#
# [Full Formal]  A photograph depicts President Trump making a fist pumping hand gesture at a memorial for 9/11 victims.
# 4394: A photograph shows President Trump making a "fist-pumping" hand gesture at a memorial for 9/11 victims.
# ----------------------------------------------------------------------------------------------------
# [Original]  Brian Kelley and Tyler Hubbard from the band Florida Georgia Line have announced that they are getting married.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Brian Kelley and Tyler Hubbard, who perform in Florida Georgia Line, have revealed that they are getting married.
#
# [Full Formal]  Brian Kelley and Tyler Hubbard, who perform in Florida Georgia Line, have revealed that they are getting married.
# 4395: Brian Kelley and Tyler Hubbard from the band Florida Georgia Line have announced that they are getting married.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Customs Agents Board a Bus in Florida Asking for Proof of Citizenship?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Did the Customs agents board a bus in Florida to ask for proof of citizenship?
#
# [Full Formal]  Did the Customs agents board a bus in Florida to ask for proof of citizenship?
# 4396: Did Customs Agents Board a Bus in Florida Asking for Proof of Citizenship?
# ----------------------------------------------------------------------------------------------------
# [Original]  Donald Trump called Abraham Lincoln a traitor.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Donald Trump has called Abraham Lincoln a traitor.
#
# [Full Formal]  Donald Trump has called Abraham Lincoln a traitor.
# 4397: Donald Trump called Abraham Lincoln a traitor.
# ----------------------------------------------------------------------------------------------------
# [Original]  A CDC doctor who swarned the public that flu shots had caused a "deadly flu epidemic" was found dead:
# ----------------------------------------------------------------------------------------------------
# [Formal]  A doctor at the CDC, who warned the public that flu shots caused a deadly flu epidemic, was found dead
#
# [Full Formal]  A doctor at the CDC, who warned the public that flu shots caused a deadly flu epidemic, was found dead
# 4398: A CDC doctor who swarned the public that flu shots had caused a "deadly flu epidemic" was found dead:
# ----------------------------------------------------------------------------------------------------
# [Original]  Warren Buffett quipped that he could end the deficit by passing "a law that says anytime there is a deficit of more than 3% of GDP, all sitting members of Congress are ineligible for re-election.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Warren Buffett predicted that he could end the deficit by passing a law that says whenever there is a deficit of more than 3% of GDP
#
# [Full Formal]  Warren Buffett predicted that he could end the deficit by passing a law that says whenever there is a deficit of more than 3% of GDP
# 4399: Warren Buffett quipped that he could end the deficit by passing "a law that says anytime there is a deficit of more than 3% of GDP, all sitting members of Congress are ineligible for re-election.
# ----------------------------------------------------------------------------------------------------
# [Original]  Was White Supremacist Who Killed Protester a Democrat Who Visited Obama in Oval Office?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Is it a white supremacy who killed a protester, but a democrat visited Obama in the Oval Office?
#
# [Full Formal]  Is it a white supremacy who killed a protester, but a democrat visited Obama in the Oval Office?
# 4400: Was White Supremacist Who Killed Protester a Democrat Who Visited Obama in Oval Office?
# ----------------------------------------------------------------------------------------------------
# [Original]  WikiLeaks documents revealed campaign head John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Documents from WikiLeaks revealed that Campaign Chief John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect
#
# [Full Formal]  Documents from WikiLeaks revealed that Campaign Chief John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect
# 4401: WikiLeaks documents revealed campaign head John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect.
# ----------------------------------------------------------------------------------------------------
# [Original]  Covfefe means something, anything.
# ----------------------------------------------------------------------------------------------------
# [Formal]  'Covfefe' means something, anything.
#
# [Full Formal]  'Covfefe' means something, anything.
# 4402: Covfefe means something, anything.
# ----------------------------------------------------------------------------------------------------
# [Original]  An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
# ----------------------------------------------------------------------------------------------------
# [Formal]  An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
#
# [Full Formal]  An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
# 4403: An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
# ----------------------------------------------------------------------------------------------------
# [Original]  A loon appears on Canada's one-dollar coin because the original dies, featuring a different design, were lost in transit.
# ----------------------------------------------------------------------------------------------------
# [Formal]  A loon appears on the Canadian one dollar coin because the original dies and a different design were lost in transit.
#
# [Full Formal]  A loon appears on the Canadian one dollar coin because the original dies and a different design were lost in transit.
# 4404: A loon appears on Canada's one-dollar coin because the original dies, featuring a different design, were lost in transit.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Fox News Use an Image of Patti LaBelle During Their Aretha Franklin Tribute?
# ----------------------------------------------------------------------------------------------------
# [Formal]  Did Fox News utilize an image of Patti LaBelle during their Aretha Franklin tribute?
#
# [Full Formal]  Did Fox News utilize an image of Patti LaBelle during their Aretha Franklin tribute?
# 4405: Did Fox News Use an Image of Patti LaBelle During Their Aretha Franklin Tribute?
# ----------------------------------------------------------------------------------------------------
# [Original]  The US government cancelled all 4th of July fireworks due to terror fears.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The United States government cancelled all fireworks on the Fourth of July due to terror fears.
#
# [Full Formal]  The United States government cancelled all fireworks on the Fourth of July due to terror fears.
# 4406: The US government cancelled all 4th of July fireworks due to terror fears.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Obama issued an order banning U.S. military personnel from using the word "Christmas."
# ----------------------------------------------------------------------------------------------------
# [Formal]  President Obama recently issued an order banning military personnel from using the term Christmas.
#
# [Full Formal]  President Obama recently issued an order banning military personnel from using the term Christmas.
# 4407: President Obama issued an order banning U.S. military personnel from using the word "Christmas."
# ----------------------------------------------------------------------------------------------------
# [Original]  Tiny Hand Sir
# ----------------------------------------------------------------------------------------------------
# [Formal]  The name is Tiny Hand Sir
#
# [Full Formal]  The name is Tiny Hand Sir
# 4408: Tiny Hand Sir
# ----------------------------------------------------------------------------------------------------
# [Original]  A local identification card program in Chicago would allow undocumented immigrants to vote in United States elections.
# ----------------------------------------------------------------------------------------------------
# [Formal]  A local ID card program in Chicago would allow undocumented immigrants to vote in United States elections.
#
# [Full Formal]  A local ID card program in Chicago would allow undocumented immigrants to vote in United States elections.
# 4409: A local identification card program in Chicago would allow undocumented immigrants to vote in United States elections.
# ----------------------------------------------------------------------------------------------------
# [Original]  Placing a coin on top of a frozen glass of water in your freezer can help you tell if your freezer experienced a significant loss of power in your absence.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Placing a coin on top of a frozen glass of water in your freezer can help you determine if your freezer experienced a significant loss
#
# [Full Formal]  Placing a coin on top of a frozen glass of water in your freezer can help you determine if your freezer experienced a significant loss
# 4410: Placing a coin on top of a frozen glass of water in your freezer can help you tell if your freezer experienced a significant loss of power in your absence.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Trump has ordered the construction of concentration camps in the U.S.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The president has ordered construction of concentration camps.
#
# [Full Formal]  The president has ordered construction of concentration camps.
# 4411: President Trump has ordered the construction of concentration camps in the U.S.
# ----------------------------------------------------------------------------------------------------
# [Original]  The federal government passed a law permitting police officers to shoot dogs if they bark or move.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The federal government passed a law permitting police officers to shoot dogs if they bark or move.
#
# [Full Formal]  The federal government passed a law permitting police officers to shoot dogs if they bark or move.
# 4412: The federal government passed a law permitting police officers to shoot dogs if they bark or move.
# ----------------------------------------------------------------------------------------------------
# [Original]  Breast milk is glittery gold under a microscope.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Breast milk has an attractive glimmer that is detectable under a microscope.
#
# [Full Formal]  Breast milk has an attractive glimmer that is detectable under a microscope.
# 4413: Breast milk is glittery gold under a microscope.
# ----------------------------------------------------------------------------------------------------
# [Original]  Penguins fall over onto their backs while trying to observe airplanes flying overhead.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Penguins can fall onto their backs while watching airplanes fly overhead.
#
# [Full Formal]  Penguins can fall onto their backs while watching airplanes fly overhead.
# 4414: Penguins fall over onto their backs while trying to observe airplanes flying overhead.
# ----------------------------------------------------------------------------------------------------
# [Original]  Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out to Al Gore.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Irena Sendler was credited with saving 2,500 Polish Jews from the Holocaust. She was a candidate for the 2007 Nobel Peace Prize, but
#
# [Full Formal]  Irena Sendler was credited with saving 2,500 Polish Jews from the Holocaust. She was a candidate for the 2007 Nobel Peace Prize, but
# 4415: Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out to Al Gore.
# ----------------------------------------------------------------------------------------------------
# [Original]  Actor Robert De Niro blasted Donald Trump in a video meant to encourage people to vote.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Robert De Niro slammed Donald Trump in a video meant to encourage people to vote.
#
# [Full Formal]  Robert De Niro slammed Donald Trump in a video meant to encourage people to vote.
# 4416: Actor Robert De Niro blasted Donald Trump in a video meant to encourage people to vote.
# ----------------------------------------------------------------------------------------------------
# [Original]  Radiation from the 2011 Fukushima nuclear disaster has caused 100% infant mortality among orca whales.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The radiation from the Fukushima nuclear disaster in 2011, caused an infant death rate of 100% in orca whales.
#
# [Full Formal]  The radiation from the Fukushima nuclear disaster in 2011, caused an infant death rate of 100% in orca whales.
# 4417: Radiation from the 2011 Fukushima nuclear disaster has caused 100% infant mortality among orca whales.
# ----------------------------------------------------------------------------------------------------
# [Original]  Fire and smoke billowing from the vicinity of the Eiffel Tower were evidence of a Bastille Day terrorist attack in Paris.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The smoke and fire coming from the Eiffel Tower were evidence of a terrorist attack on Bastille Day in Paris.
#
# [Full Formal]  The smoke and fire coming from the Eiffel Tower were evidence of a terrorist attack on Bastille Day in Paris.
# 4418: Fire and smoke billowing from the vicinity of the Eiffel Tower were evidence of a Bastille Day terrorist attack in Paris.
# ----------------------------------------------------------------------------------------------------
# [Original]  ISIS members are operating a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
# ----------------------------------------------------------------------------------------------------
# [Formal]  ISIS members operate a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
#
# [Full Formal]  ISIS members operate a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
# 4419: ISIS members are operating a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
# ----------------------------------------------------------------------------------------------------
#
# [Full Formal]  Melania Trump advised that Native Americans upset with the Dakota Access Pipeline should go back to India.
# 5063: Melania Trump said that Native Americans upset about the Dakota Access Pipeline should "go back to India".
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows a 'Welcome Sign' outside of Mingo Country warning visitors that its citizens were armed and would "kill you back."
# ----------------------------------------------------------------------------------------------------
# [Formal]  A photograph shows a welcome sign outside of Mingo Country warning visitors that its citizens were armed and would kill you back.
#
# [Full Formal]  A photograph shows a welcome sign outside of Mingo Country warning visitors that its citizens were armed and would kill you back.
# 5064: A photograph shows a 'Welcome Sign' outside of Mingo Country warning visitors that its citizens were armed and would "kill you back."
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows William Harley and Arthur Davidson unveiling their first motorcycle in 1914.
# ----------------------------------------------------------------------------------------------------
# [Formal]  a photograph shows William Harley and Arthur Davidson unveiled their first motorcycle in 1914.
#
# [Full Formal]  a photograph shows William Harley and Arthur Davidson unveiled their first motorcycle in 1914.
# 5065: A photograph shows William Harley and Arthur Davidson unveiling their first motorcycle in 1914.
# ----------------------------------------------------------------------------------------------------
# [Original]  Image depicts "attitude adjustment" and "smile therapy" forced upon American housewives in the 1930s institutionalized for "not taking care of themselves" and acting "depressed."
# ----------------------------------------------------------------------------------------------------
# [Formal]  The image depicts an attitude adjustment and smile therapy forced upon American housewives in the 1930s institutionalized for being "not taking care of themselves"
#
# [Full Formal]  The image depicts an attitude adjustment and smile therapy forced upon American housewives in the 1930s institutionalized for being "not taking care of themselves"
# 5066: Image depicts "attitude adjustment" and "smile therapy" forced upon American housewives in the 1930s institutionalized for "not taking care of themselves" and acting "depressed."
# ----------------------------------------------------------------------------------------------------
# [Original]  A cook attempted to poison George Washington by feeding him tomatoes.
# ----------------------------------------------------------------------------------------------------
# [Formal]  An unwitting cook attempted to poison George Washington by feeding him tomatoes.
#
# [Full Formal]  An unwitting cook attempted to poison George Washington by feeding him tomatoes.
# 5067: A cook attempted to poison George Washington by feeding him tomatoes.
# ----------------------------------------------------------------------------------------------------
# [Original]  Cavities are contagious, primarily between intimate partners or children and caregivers.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Cavities are contagious. They tend to occur primarily between intimate partners, but it can occur between children and caregivers as well.
#
# [Full Formal]  Cavities are contagious. They tend to occur primarily between intimate partners, but it can occur between children and caregivers as well.
# 5068: Cavities are contagious, primarily between intimate partners or children and caregivers.
# ----------------------------------------------------------------------------------------------------
# [Original]  A vacationing couple staying in a foul-smelling motel room discovered a body hidden under their bed.
# ----------------------------------------------------------------------------------------------------
# [Formal]  A vacationing couple, staying in a foul-smelling motel room, discovered a body hidden under their bed.
#
# [Full Formal]  A vacationing couple, staying in a foul-smelling motel room, discovered a body hidden under their bed.
# 5069: A vacationing couple staying in a foul-smelling motel room discovered a body hidden under their bed.

# %%
df_snes.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_formal.tsv', 
                sep='\t', header=False, index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
