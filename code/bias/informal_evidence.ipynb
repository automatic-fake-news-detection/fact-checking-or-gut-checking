# %%
from google.colab import drive
import os
import sys
# !pip install transformers
drive.mount('/content/drive', force_remount=True)
sys.path.append('/content/drive/MyDrive')
print(os.getcwd())
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 6.5 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 71.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 48.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 691 kB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5
# Mounted at /content/drive
# /content

# %%
# !pip install -r /content/drive/MyDrive/styleformer/requirements.txt
# Out:
# Obtaining styleformer from git+https://github.com/PrithivirajDamodaran/Styleformer.git#egg=styleformer (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 1))
#   Cloning https://github.com/PrithivirajDamodaran/Styleformer.git to ./src/styleformer
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Styleformer.git /content/src/styleformer
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (1.10.0+cu111)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.12.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 12.6 MB/s
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 8.3 MB/s
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.8.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.0.46)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.15.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149859 sha256=0f1bf1fa9eb20413b8aa22a54bdc089075a74b794905b974c25ea55d626bca95
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: sentencepiece, python-Levenshtein, fuzzywuzzy, styleformer
#   Running setup.py develop for styleformer
# Successfully installed fuzzywuzzy-0.18.0 python-Levenshtein-0.12.2 sentencepiece-0.1.96 styleformer-0.1

# %%
# !ls /content/drive/MyDrive/styleformer/*.py
# sys.path.append('/content/drive/MyDrive/styleformer/src/styleformer')

# %%
class Styleformer():

  def __init__(self,  style=0):
    from transformers import AutoTokenizer
    from transformers import AutoModelForSeq2SeqLM
    #from styleformer import Adequacy

    self.style = style
    self.adequacy = Adequacy()
    self.model_loaded = False

    if self.style == 0:
      self.ctf_tokenizer = AutoTokenizer.from_pretrained("prithivida/informal_to_formal_styletransfer")
      self.ctf_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/informal_to_formal_styletransfer")
      print("Casual to Formal model loaded...")
      self.model_loaded = True
    elif self.style == 1:
      self.ftc_tokenizer = AutoTokenizer.from_pretrained("prithivida/formal_to_informal_styletransfer")
      self.ftc_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/formal_to_informal_styletransfer")
      print("Formal to Casual model loaded...")
      self.model_loaded = True  
    elif self.style == 2:
      self.atp_tokenizer = AutoTokenizer.from_pretrained("prithivida/active_to_passive_styletransfer")
      self.atp_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/active_to_passive_styletransfer")
      print("Active to Passive model loaded...")  
      self.model_loaded = True
    elif self.style == 3:
      self.pta_tokenizer = AutoTokenizer.from_pretrained("prithivida/passive_to_active_styletransfer")
      self.pta_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/passive_to_active_styletransfer")
      print("Passive to Active model loaded...")        
      self.model_loaded = True
    else:
      print("Only CTF, FTC, ATP and PTA are supported in the pre-release...stay tuned")

  def transfer(self, input_sentence, inference_on=0, quality_filter=0.95, max_candidates=5):
      if self.model_loaded:
        if inference_on == 0:
          device = "cpu"
        elif inference_on == 1:
          device = "cuda:0"  
        else:  
          device = "cpu"
          print("Onnx + Quantisation is not supported in the pre-release...stay tuned.")

        if self.style == 0:
          output_sentence = self._casual_to_formal(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 1:
          output_sentence = self._formal_to_casual(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 2:
          output_sentence = self._active_to_passive(input_sentence, device)
          return output_sentence        
        elif self.style == 3:
          output_sentence = self._passive_to_active(input_sentence, device)
          return output_sentence           
      else:
        print("Models aren't loaded for this style, please use the right style during init")  


  def _formal_to_casual(self, input_sentence, device, quality_filter, max_candidates):
      ftc_prefix = "transfer Formal to Casual: "
      src_sentence = input_sentence
      input_sentence = ftc_prefix + input_sentence
      input_ids = self.ftc_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ftc_model = self.ftc_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ftc_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ftc_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _casual_to_formal(self, input_sentence, device, quality_filter, max_candidates):
      ctf_prefix = "transfer Casual to Formal: "
      src_sentence = input_sentence
      input_sentence = ctf_prefix + input_sentence
      input_ids = self.ctf_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ctf_model = self.ctf_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ctf_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ctf_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _active_to_passive(self, input_sentence, device):
      atp_prefix = "transfer Active to Passive: "
      src_sentence = input_sentence
      input_sentence = atp_prefix + input_sentence
      input_ids = self.atp_tokenizer.encode(input_sentence, return_tensors='pt')
      self.atp_model = self.atp_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.atp_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.atp_tokenizer.decode(preds[0], skip_special_tokens=True).strip()

  def _passive_to_active(self, input_sentence, device):
      pta_prefix = "transfer Passive to Active: "
      src_sentence = input_sentence
      input_sentence = pta_prefix + input_sentence
      input_ids = self.pta_tokenizer.encode(input_sentence, return_tensors='pt')
      self.pta_model = self.pta_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.pta_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.pta_tokenizer.decode(preds[0], skip_special_tokens=True).strip()      

    
class Adequacy():

  def __init__(self, model_tag='prithivida/parrot_adequacy_on_BART'):
    from transformers import AutoModelForSequenceClassification, AutoTokenizer
    self.nli_model = AutoModelForSequenceClassification.from_pretrained(model_tag)
    self.tokenizer = AutoTokenizer.from_pretrained(model_tag)
    
  def filter(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      top_adequacy_phrases = []
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
            top_adequacy_phrases.append(para_phrase)
      return top_adequacy_phrases

  def score(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      adequacy_scores = {}
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
          adequacy_scores[para_phrase] = adequacy_score
      return adequacy_scores

# %%
import torch
import warnings
import transformers
import re
warnings.filterwarnings("ignore")

sf = Styleformer(style = 1)
# Out:
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Formal to Casual model loaded...

# %%
# !nvidia-smi
# Out:
# Fri Dec  3 06:41:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import os

snes_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes.tsv"
snes_snippets_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes_snippets.tsv"

snes_col_list = ["claimID", "claim", "label", "claimURL", "reason", "categories", "speaker",
                 "checker", "tags", "articleTitle", "publishDate", "claimDate", "entities"]
df_snes = pd.read_csv(snes_path, sep='\t', names=snes_col_list, index_col=False)

snes_snippets_col_list = ["rank_position", "snippet1", "snippet2", "snippet3", "snippet4", 
                 "snippet5", "snippet6", "snippet7", "snippet8", "snippet9", "snippet10"]
df_snippets = pd.read_csv(snes_snippets_path, sep='\t', names=snes_snippets_col_list, index_col=False)

# %%
df_snippets.iloc[0]['snippet1']
# Out:
# 'Oct 24, 2016 ... Q: Did Pope Francis endorse Donald Trump? ... “Pope Francis Shocks World,  Endorses Donald Trump for President, Releases Statement.'

# %%
df_snippets
# Out:
#      rank_position  ... snippet10
# 0       snes-04484  ...    filler
# 1       snes-03162  ...    filler
# 2       snes-05436  ...    filler
# 3       snes-02901  ...    filler
# 4       snes-03347  ...    filler
# ...            ...  ...       ...
# 2495    snes-00316  ...    filler
# 2496    snes-03070  ...    filler
# 2497    snes-00049  ...    filler
# 2498    snes-00836  ...    filler
# 2499    snes-04504  ...    filler
#
# [2500 rows x 11 columns]

# %%
def get_formal_snippet(snippet):
  snippet = snippet.strip()
  if snippet == 'filler' or snippet == '':
    return snippet
  full_target = ""  
  split_sentences = re.split(r'\.\.\.+', snippet)
  for split_sentence in split_sentences:
    if split_sentence.strip() != '':
      target_sentence = sf.transfer(split_sentence, inference_on=1)
      print("-" *100)
      print("[Casual] ", split_sentence)
      print("-" *100)
      if target_sentence is not None:
          print("[Formal] ",target_sentence)
          print()
          if full_target != "":
            full_target += " ... " + target_sentence
          else:
            full_target += target_sentence
      else:
          print("No good quality transfers available !")
  print("[Full Formal] ", full_target)
  return full_target

for index, row in df_snippets.iterrows():
  print(str(index+1) + " snippet 1")
  df_snippets.at[index, 'snippet1'] = get_formal_snippet(row['snippet1'])
  print(str(index+1) + " snippet 2")
  df_snippets.at[index, 'snippet2'] = get_formal_snippet(row['snippet2'])
  print(str(index+1) + " snippet 3")
  df_snippets.at[index, 'snippet3'] = get_formal_snippet(row['snippet3'])
  print(str(index+1) + " snippet 4")
  df_snippets.at[index, 'snippet4'] = get_formal_snippet(row['snippet4'])
  print(str(index+1) + " snippet 5")
  df_snippets.at[index, 'snippet5'] = get_formal_snippet(row['snippet5'])
  print(str(index+1) + " snippet 6")
  df_snippets.at[index, 'snippet6'] = get_formal_snippet(row['snippet6'])
  print(str(index+1) + " snippet 7")    
  df_snippets.at[index, 'snippet7'] = get_formal_snippet(row['snippet7'])
  print(str(index+1) + " snippet 8")
  df_snippets.at[index, 'snippet8'] = get_formal_snippet(row['snippet8']) 
  print(str(index+1) + " snippet 9")
  df_snippets.at[index, 'snippet9'] = get_formal_snippet(row['snippet9']) 
  print(str(index+1) + " snippet 10")
  df_snippets.at[index, 'snippet10'] = get_formal_snippet(row['snippet10']) 

df_snippets.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_informal_snippets.tsv', 
               sep='\t', header=False, index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------------------------------------------------------------------------
# [Casual]   Yes, Obama has  an army of agitators — numbering more than 30,000 — who
# ----------------------------------------------------------------------------------------------------
# [Formal]  Yes, Obama has a force of agitators akin to over 30 000
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   them from a  bunker less than two miles from the White House.
# ----------------------------------------------------------------------------------------------------
# [Formal]  from a bunker less than 2 miles from the white house.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Around The Web.
# ----------------------------------------------------------------------------------------------------
# [Formal]  around the web
#
# [Full Formal]  11 feb 2017 ... As former president Barack Obama said, he was heartened by anti-Trump protests and was sending a message of approval to his troops ... Yes, Obama has a force of agitators akin to over 30 000 ... from a bunker less than 2 miles from the white house. ... around the web
# 2475 snippet 2
# ----------------------------------------------------------------------------------------------------
# [Casual]  Feb 13, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  FEB 13, 2017
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Throughout American history, most ex-presidents have chosen to move
# ----------------------------------------------------------------------------------------------------
# [Formal]  almost all ex presidents have always chosen to move
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   His  new home is less than two miles from the White House, and from
# ----------------------------------------------------------------------------------------------------
# [Formal]  not too far from the white house...his new home.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   in many of the  protests and riots that have been popping up around the
# ----------------------------------------------------------------------------------------------------
# [Formal]  in many of the protests and riots that have been popping up around the country
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   When former  President Barack Obama said he was “heartened” by anti-Trump protests,
# ----------------------------------------------------------------------------------------------------
# [Formal]  Especially when a former president Barack Obama says that he is heartened by anti-Trump protests
#
# [Full Formal]  FEB 13, 2017 ... almost all ex presidents have always chosen to move ... not too far from the white house...his new home. ... in many of the protests and riots that have been popping up around the country ... Especially when a former president Barack Obama says that he is heartened by anti-Trump protests
# 2475 snippet 3
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 6, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Aug 6, 2017
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Organizing for Action, a hub of the Democratic protest movement,
# ----------------------------------------------------------------------------------------------------
# [Formal]  organizing for action the hub of the democratic protest movement
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Then- President Barack Obama speaks during an Organizing for Action
# ----------------------------------------------------------------------------------------------------
# [Formal]  then, president barack obama speaking at Organizing for Action
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   for its next  showdown this fall — battling President Donald Trump's
# ----------------------------------------------------------------------------------------------------
# [Formal]  for its next showdown this fall... battling president dnntrump
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   “Our members are  home.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Our members are here
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   while he was in the White House, OFA returned it to him in January.
# ----------------------------------------------------------------------------------------------------
# [Formal]  OFA returned it to him in January while he was in the White House.
#
# [Full Formal]  Aug 6, 2017 ... organizing for action the hub of the democratic protest movement ... then, president barack obama speaking at Organizing for Action ... for its next showdown this fall... battling president dnntrump ... Our members are here ... OFA returned it to him in January while he was in the White House.
# 2475 snippet 4
# ----------------------------------------------------------------------------------------------------
# [Casual]  Sep 7, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  Sep 7th, 2018
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Former President Barack Obama on Friday launched a direct attack on
# ----------------------------------------------------------------------------------------------------
# [Formal]  former president barack obama on friday attacked obama in direct way
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   on  President Donald Trump and Republicans and called on Americans
# ----------------------------------------------------------------------------------------------------
# [Formal]  on ptewr.donald trump and republicans and called on americans
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    referencing the "crazy stuff coming out of this White House," Obama
# ----------------------------------------------------------------------------------------------------
# [Formal]  referring to the crazy stuff coming out of this white house, Obama
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Here is a  transcript of Obama's speech as provided by his office:
# ----------------------------------------------------------------------------------------------------
# [Formal]  hey here's the transcript of the obama speech he gave..it is from his office..
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   It is good to be home.
# ----------------------------------------------------------------------------------------------------
# [Formal]  yeah, home, home is a good thing
#
# [Full Formal]  Sep 7th, 2018 ... former president barack obama on friday attacked obama in direct way ... on ptewr.donald trump and republicans and called on americans ... referring to the crazy stuff coming out of this white house, Obama ... hey here's the transcript of the obama speech he gave..it is from his office.. ... yeah, home, home is a good thing
# 2475 snippet 5
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jan 8, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Jan 8, 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   President Barack Obama greets members of the U.S. military during a
# ----------------------------------------------------------------------------------------------------
# [Formal]  Obama, on the job greeting members of the military
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   About 36  percent said they approve of his job as commander in chief.
# ----------------------------------------------------------------------------------------------------
# [Formal]  around 36 percent said they approve of his job as commander in chief.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   of progress" with  the military by praising the White House moves as
# ----------------------------------------------------------------------------------------------------
# [Formal]  "of progress" with the military, by praising the White House moves as an example.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   aftermath of Donald Trump's  election victory, showed that more than 60
# ----------------------------------------------------------------------------------------------------
# [Formal]  after Donald Trump won his election.. 60 people saw it.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Around The Web
# ----------------------------------------------------------------------------------------------------
# [Formal]  Around the Web
#
# [Full Formal]  Jan 8, 2017. ... Obama, on the job greeting members of the military ... around 36 percent said they approve of his job as commander in chief. ... "of progress" with the military, by praising the White House moves as an example. ... after Donald Trump won his election.. 60 people saw it. ... Around the Web
# 2475 snippet 6
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 20, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Aug 20, 2017
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Army brass know that if every black soldier quit in protest over
# ----------------------------------------------------------------------------------------------------
# [Formal]  army brass know if every black soldier quit, they'll quit
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   stand of the Joint  Chiefs of Staff against their commander in chief.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Joint Chiefs of Staff stand against their commander in chief
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   every president following  John F. Kennedy – until Barack Obama
# ----------------------------------------------------------------------------------------------------
# [Formal]  every president since john f. kennedy till barack obama
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   to serve as White House chief of staff  since Alexander Haig worked for
# ----------------------------------------------------------------------------------------------------
# [Formal]  to be white house chief of staff since it worked for amos haige
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Former IDF chief Benny Gantz.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Former IDF chief Benny Gantz
#
# [Full Formal]  Aug 20, 2017 ... army brass know if every black soldier quit, they'll quit ... Joint Chiefs of Staff stand against their commander in chief ... every president since john f. kennedy till barack obama ... to be white house chief of staff since it worked for amos haige ... Former IDF chief Benny Gantz
# 2475 snippet 7
# ----------------------------------------------------------------------------------------------------
# [Casual]  Feb 10, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Feb 10, 2017
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   But with Trump in the White House, the relaunched OFA will claim a
# ----------------------------------------------------------------------------------------------------
# [Formal]  but with him in the white house the relaunched OFA will get a 'boost'
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   home to  key senators as part of its campaign to defend Obama's signature healthcare law.  To run that campaign, the group hired Saumya Narechania -- the former
# ----------------------------------------------------------------------------------------------------
# [Formal]  home to some key senators as part of its campaign to defend Obama's signature healthcare law, the group hired Saumya Narechania -- the
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   a  grassroots army it could command at will to push Obama's agenda
# ----------------------------------------------------------------------------------------------------
# [Formal]  a grassroots army it can command at will to push Obama's agenda
#
# [Full Formal]  Feb 10, 2017 ... but with him in the white house the relaunched OFA will get a 'boost' ... home to some key senators as part of its campaign to defend Obama's signature healthcare law, the group hired Saumya Narechania -- the ... a grassroots army it can command at will to push Obama's agenda
# 2475 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jun 18, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  18 Jun 2018
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Adam Entous on how the President, Israel, and the Gulf states plan to
# ----------------------------------------------------------------------------------------------------
# [Formal]  Adam Entous on how the PRESIDENT, israel, and the Gulf States are going.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    Netanyahu believed that Barack Obama had “no special feeling” for
# ----------------------------------------------------------------------------------------------------
# [Formal]  Netanyahu thought that Barack Obama had a 'no special feeling' for him
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   His  Administration had provided the country with immense military and intelligence  support.
# ----------------------------------------------------------------------------------------------------
# [Formal]  his administration provided the country with huge military and intelligence support.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Even before Trump entered the White House, Israeli officials talked
# ----------------------------------------------------------------------------------------------------
# [Formal]  even before trump got into the white house, israeli officials talked about it
#
# [Full Formal]  18 Jun 2018 ... Adam Entous on how the PRESIDENT, israel, and the Gulf States are going. ... Netanyahu thought that Barack Obama had a 'no special feeling' for him ... his administration provided the country with huge military and intelligence support. ... even before trump got into the white house, israeli officials talked about it
# 2475 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]  Nov 16, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  nov 16 2018.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Defense Department officials doubt President Trump has fully
# ----------------------------------------------------------------------------------------------------
# [Formal]  Defense Dept. says it doubts president Trump's full grasp of the situation.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Afterward, he  returned to the White House to address a group of veterans.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Then he went back to the white house to talk to vets.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   his leadership, the  American armed forces will be “the finest that our
# ----------------------------------------------------------------------------------------------------
# [Formal]  Under his leadership, the armed forces will be tha finest that our people can get.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   But the one they hate, invade and terrorise are.
# ----------------------------------------------------------------------------------------------------
# [Formal]  but the ones they hate invade terrorise.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Something feminists should  learn.
# ----------------------------------------------------------------------------------------------------
# [Formal]  something feminists should learn.
#
# [Full Formal]  I wish America was more worried about offending God and not more about offending people ... what people are saying. ... check out some ideas about Clint Eastwood Kids ... but the ones they hate invade terrorise. ... something feminists should learn.
# 2476 snippet 4
# ----------------------------------------------------------------------------------------------------
# [Casual]  Hopefully, more and more people will begin to feel their story is somehow part of
# ----------------------------------------------------------------------------------------------------
# [Formal]  hopefully more and more people will begin to feel their story is somehow part of the story
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   It allows us to say that those whose health care or tuition may rise faster than
# ----------------------------------------------------------------------------------------------------
# [Formal]  So it's like those who pay for sickcare or tuition are going to rise faster then that
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   regard for each other, the idea that everybody has a stake in the country, that
# ----------------------------------------------------------------------------------------------------
# [Formal]  regard for each other, the idea that everybody has a stake in the country, that everybody has to share.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   in my faith in God and my faith in the American people - that working together
# ----------------------------------------------------------------------------------------------------
# [Formal]  in my faith in god and in americans... working together
#
# [Full Formal]  hopefully more and more people will begin to feel their story is somehow part of the story ... So it's like those who pay for sickcare or tuition are going to rise faster then that ... regard for each other, the idea that everybody has a stake in the country, that everybody has to share. ... in my faith in god and in americans... working together
# 2476 snippet 5
# ----------------------------------------------------------------------------------------------------
# [Casual]  Dec 7, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  Dec 7, 2018
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Have you ever heard some other lyrics? From say…
# ----------------------------------------------------------------------------------------------------
# [Formal]  Ever heard some other lyrics?say...
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Now the song – baby it's  cold outside is offensive
# ----------------------------------------------------------------------------------------------------
# [Formal]  now the song baby it's cold outside is offensive
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Clint Eastwood once said, “I wish America was more  concerned about offending God and less concerned about offending people.”
# ----------------------------------------------------------------------------------------------------
# [Formal]  clint eastwood once said...I wish america were more concerned about offending god and less concerned about people.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   I  should not have to start or end a statement with “no offense.
# ----------------------------------------------------------------------------------------------------
# [Formal]  no offense, I shouldn't have to start or end a statement with that.
#
# [Full Formal]  Dec 7, 2018 ... Ever heard some other lyrics?say... ... now the song baby it's cold outside is offensive ... clint eastwood once said...I wish america were more concerned about offending god and less concerned about people. ... no offense, I shouldn't have to start or end a statement with that.
# 2476 snippet 6
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jan 27, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Jan 27 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   It's less likely to drop or break; it will open in your mouth.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It's less likely to drop or break, and it'll open in your mouth.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   prefers to pair sushi  with a dry sake and says if you're more interested in wine,
# ----------------------------------------------------------------------------------------------------
# [Formal]  likes to pair sushi with dry sake and says if you're more interested in wine...
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   The Ume Matsu is a  selection of five different fish served sashimi
# ----------------------------------------------------------------------------------------------------
# [Formal]  ume matsu, 5 different fish served as sashimi
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   David Eastwood says
# ----------------------------------------------------------------------------------------------------
# [Formal]  David Eastwood says,
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   My  suggestion, if you are concerned about offending the chef, pick a nice
# ----------------------------------------------------------------------------------------------------
# [Formal]  and if ur concerned about offending the chef, pick a nice a nice one.
#
# [Full Formal]  Jan 27 2017. ... It's less likely to drop or break, and it'll open in your mouth. ... likes to pair sushi with dry sake and says if you're more interested in wine... ... ume matsu, 5 different fish served as sashimi ... David Eastwood says, ... and if ur concerned about offending the chef, pick a nice a nice one.
# 2476 snippet 7
# ----------------------------------------------------------------------------------------------------
# [Casual]  Feb 8, 2013
# ----------------------------------------------------------------------------------------------------
# [Formal]  Feb 8, 2013
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Since his death, a few reporters have heard trickles of other stories.
# ----------------------------------------------------------------------------------------------------
# [Formal]  some reporters have heard of other stories since he died.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Then he  turned slightly and fired twice more, hitting the second man twice in
# ----------------------------------------------------------------------------------------------------
# [Formal]  Then he turned slightly, fired twice more, hitting the second man twice in the process.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   He said the  officers were very understanding, that they didn't want to
# ----------------------------------------------------------------------------------------------------
# [Formal]  He said the officers were great at understanding that they didn't want to do it.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   In every sense of the  word, Chris Kyle was a true American badass.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Chris Kyle was a true 'American badass', in every sense of the word.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Scott shauger.
# ----------------------------------------------------------------------------------------------------
# [Formal]  scott shauger
#
# [Full Formal]  Feb 8, 2013 ... some reporters have heard of other stories since he died. ... Then he turned slightly, fired twice more, hitting the second man twice in the process. ... He said the officers were great at understanding that they didn't want to do it. ... Chris Kyle was a true 'American badass', in every sense of the word. ... scott shauger
# 2476 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jackson Katz: There's the America that recoils in horror whenever a brutal mass
# ----------------------------------------------------------------------------------------------------
# [Formal]  The America that looks like it's coming from hell when people are killed.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Panelist: One thing we can say for certain is that men are more violent than  women.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Panelist One thing we can honestly say for sure is that men are more violent than women.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   mental health care, and addressing a culture that too often glorifies  guns and
# ----------------------------------------------------------------------------------------------------
# [Formal]  mental health care, and addressing a culture that too often glorifies guns and guns.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Clint Eastwood: You don't just come in and insult a man in his own  shop.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Clint Eastwood, Don't come in and just insult a guy in his own shop
#
# [Full Formal]  The America that looks like it's coming from hell when people are killed. ... Panelist One thing we can honestly say for sure is that men are more violent than women. ... mental health care, and addressing a culture that too often glorifies guns and guns. ... Clint Eastwood, Don't come in and just insult a guy in his own shop
# 2476 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]  Mar 20, 2013
# ----------------------------------------------------------------------------------------------------
# [Formal]  20 Mar 2013
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   In other words, the invented cowboy tradition is part of the rise of both
# ----------------------------------------------------------------------------------------------------
# [Formal]  i mean the invented cowboy tradition is a big part of both of them
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   On the  contrary, practically all the westerns that any of us would wish to see again
# ----------------------------------------------------------------------------------------------------
# [Formal]  pretty much every western we would like to see again
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    What is more, once the late western movie had itself become infected
# ----------------------------------------------------------------------------------------------------
# [Formal]  And once the late western movie itself got infected
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   but who  doesn't know what he's doing or doesn't care except about ripping
# ----------------------------------------------------------------------------------------------------
# [Formal]  but who doesnt know what he's doing or cares, thats just about ripping
#
# [Full Formal]  20 Mar 2013 ... i mean the invented cowboy tradition is a big part of both of them ... pretty much every western we would like to see again ... And once the late western movie itself got infected ... but who doesnt know what he's doing or cares, thats just about ripping
# 2476 snippet 10
# 2477 snippet 1
# ----------------------------------------------------------------------------------------------------
# [Casual]  Dec 7, 2015
# ----------------------------------------------------------------------------------------------------
# [Formal]  Dec 7 2015
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Rumors, such as the one that Arby's serves "liquid meat," have
# ----------------------------------------------------------------------------------------------------
# [Formal]  Rumors such as Arby's selling liquid meat are out there
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   at how the  sausage — or roast beef — gets made at Arby's new Manhattan location. 1/9
# ----------------------------------------------------------------------------------------------------
# [Formal]  at how the sausage — or roast beef — gets made at arby's new Manhattan location 1/9
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    The sandwich is topped with mayonnaise and BBQ sauce, but not the
# ----------------------------------------------------------------------------------------------------
# [Formal]  The canapee and BBQ sauce go over the sandwich, the sauce is not there.
#
# [Full Formal]  Dec 7 2015 ... Rumors such as Arby's selling liquid meat are out there ... at how the sausage — or roast beef — gets made at arby's new Manhattan location 1/9 ... The canapee and BBQ sauce go over the sandwich, the sauce is not there.
# 2477 snippet 2
# ----------------------------------------------------------------------------------------------------
# [Casual]  I will tell you how to make a roast beef that is much better than Arbys.
# ----------------------------------------------------------------------------------------------------
# [Formal]  the best roast beef to make is far better than arby's i'll tell ya
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   I'd  recommend grinding some lean beef to a paste, blend in powdered garlic, onion,  salt,
# ----------------------------------------------------------------------------------------------------
# [Formal]  grind some lean beef to paste, mix in powdered garlic, onion, salt, pepper
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Perform a quick dip in a hot liquid, I usually prefer stock but you can get by  with
# ----------------------------------------------------------------------------------------------------
# [Formal]  give it a quick dip in a hot liquid i prefer stock but u can get by with some
#
# [Full Formal]  the best roast beef to make is far better than arby's i'll tell ya ... grind some lean beef to paste, mix in powdered garlic, onion, salt, pepper ... give it a quick dip in a hot liquid i prefer stock but u can get by with some
# 2477 snippet 3
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 23, 2007
# ----------------------------------------------------------------------------------------------------
# [Formal]  Aug 23 2007
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Arby's roast beef is not made from some sort of meat-flavoured congealed gel. I  think, just my own
# ----------------------------------------------------------------------------------------------------
# [Formal]  Arby's Roast Beef isn't made from a meat flavoured congealed gel i think, just my own
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Second, until I can see with my own eyes the Arby's roast  beef being made I stand by the Slurry, Gelatin and who knows what else. a.  ariluv230
# ----------------------------------------------------------------------------------------------------
# [Formal]  2. until I can see on my own eye the Arbys roast beef being made I stand by the Slurry, Gelatin and who knows what else
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   With the seasoned coating, and dipped in Heinz bbq sauce.
# ----------------------------------------------------------------------------------------------------
# [Formal]  with the seasoned coating, and dipped in heinz bbq sauce.
#
# [Full Formal]  Aug 23 2007 ... Arby's Roast Beef isn't made from a meat flavoured congealed gel i think, just my own ... 2. until I can see on my own eye the Arbys roast beef being made I stand by the Slurry, Gelatin and who knows what else ... with the seasoned coating, and dipped in heinz bbq sauce.
# 2477 snippet 4
# ----------------------------------------------------------------------------------------------------
# [Casual]  Arby's "rost beef" is emulsified beef, reformed with meat glue. That's how they can  get product consistency. Think of it as hot dogs sliced thin. Ahhh, yes, sources.
# ----------------------------------------------------------------------------------------------------
# [Formal]  arby's rost beef emulsified beef reformed with meat glue.thats how they get product consistency...
#
# [Full Formal]  arby's rost beef emulsified beef reformed with meat glue.thats how they get product consistency...
# 2477 snippet 5
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 26, 2016
# ----------------------------------------------------------------------------------------------------
# [Formal]  Aug 26th, 2016
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Another claim says that Arby's roast beef is made from a paste, gel, powder or  liquid. Again, this one is false, according to internet myth buster
# ----------------------------------------------------------------------------------------------------
# [Formal]  Another claim says Arby's roast beef is made from a paste, gel, powder, or liquid again, this one is false, according to
#
# [Full Formal]  Aug 26th, 2016 ... Another claim says Arby's roast beef is made from a paste, gel, powder, or liquid again, this one is false, according to
# 2477 snippet 6
# ----------------------------------------------------------------------------------------------------
# [Casual]  Oct 4, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  oc 4 2018
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Myth: Chicken McNuggets are made with pink slime. Chicken nuggets
# ----------------------------------------------------------------------------------------------------
# No good quality transfers available !
# ----------------------------------------------------------------------------------------------------
# [Casual]   Myth:  Arby's uses “liquid meat”
# ----------------------------------------------------------------------------------------------------
# [Formal]  Myth: Arbys uses liquid meat
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   The claim is the beef is a reconstituted liquid, gel,  powder, or paste. While it's true their roast beef sandwiches are weirdly uniform,  the company has posted plenty of videos of their roasts being sliced.
# ----------------------------------------------------------------------------------------------------
# [Formal]  they say that the beef is a reconstituted liquid gel powder, or paste....yeah, their roast beef sandwiches are weirdly uniform
#
# [Full Formal]  oc 4 2018 ... Myth: Arbys uses liquid meat ... they say that the beef is a reconstituted liquid gel powder, or paste....yeah, their roast beef sandwiches are weirdly uniform
# 2477 snippet 7
# ----------------------------------------------------------------------------------------------------
# [Casual]  Mar 28, 2015
# ----------------------------------------------------------------------------------------------------
# [Formal]  mar 28, 2015
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Arby's Roast Beef. John S. Loading
# ----------------------------------------------------------------------------------------------------
# [Formal]  arby's roast beef.john s.loading
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Unsubscribe from John S? Cancel  Unsubscribe. Working
# ----------------------------------------------------------------------------------------------------
# [Formal]  unsubscribe from john s? cancel unsubscribe working on it
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   SubscribeSubscribedUnsubscribe 127.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Subscribe Subscribe Subscribe Unsubscribe 127
#
# [Full Formal]  mar 28, 2015 ... arby's roast beef.john s.loading ... unsubscribe from john s? cancel unsubscribe working on it ... Subscribe Subscribe Subscribe Unsubscribe 127
# 2477 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  Oct 10, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  Oct 10, 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   fast food hamburgers never go bad, frozen desserts use pig fat instead of dairy  or that Arby's roast beef is made from a form of a liquid gel.
# ----------------------------------------------------------------------------------------------------
# [Formal]  fast food hamburgers never go bad frozen desserts use pig fat instead of dairy or Arbys roast beef is made from a liquid gel.
#
# [Full Formal]  Oct 10, 2017. ... fast food hamburgers never go bad frozen desserts use pig fat instead of dairy or Arbys roast beef is made from a liquid gel.
# 2477 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]  It costs $10, and has some of every meat Arby's sells. Naturally
# ----------------------------------------------------------------------------------------------------
# ...
# [Casual]   Police officer could face misconduct hearing over failure to act on tip-offs
# ----------------------------------------------------------------------------------------------------
# [Formal]  A cop may get a misconduct hearing for failing to act on tip-offs

#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Josie Gibson EXCLUSIVE 'I didn't want to be another statistic':
# ----------------------------------------------------------------------------------------------------
# [Formal]  Josie Gibson I didn't wanna be another statistic.
#
# [Full Formal]  Mar 2 2016 ... fortunately as an experiancer with a penis of 30 years, I'm more of a pro. ... in september 2012, a two week old baby died at a Brooklyn hospital after contracting herpes. ... ironically, his death coincided with International Women's Day. ... Josie Gibson I didn't wanna be another statistic.
# 2500 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  the of to a and in that is for on it with as was he his but at are be by have from has
# ----------------------------------------------------------------------------------------------------
# [Formal]  a to for on it with as was he his but at are be by have from has
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   just into years now most after even do last over first other year could also two
# ----------------------------------------------------------------------------------------------------
# [Formal]  just past years now, most after even last the next year.. well, maybe two
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    th isnt yearold started close report talk began team move george together room
# ----------------------------------------------------------------------------------------------------
# [Formal]  the isnt yearold started close report talk began team move george together room
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   familiar illegal peter arab murder planned airline officers drugs features twice
# ----------------------------------------------------------------------------------------------------
# [Formal]  Famous, unconstitutional, illegal, petrochemical murder planned by airline officers, drugs features twice
#
# [Full Formal]  a to for on it with as was he his but at are be by have from has ... just past years now, most after even last the next year.. well, maybe two ... the isnt yearold started close report talk began team move george together room ... Famous, unconstitutional, illegal, petrochemical murder planned by airline officers, drugs features twice
# 2500 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]   https://www.daytondailynews.com/sports/college/after-two-close-wins-florida-
# ----------------------------------------------------------------------------------------------------
# [Formal]  https://www.daytondailynews.com/sports/college/after-two close wins florida
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -will-not-pursue-charges-dayton-dead-dog-case/kOCmMAd4l9qk6qiEaqjBjJ/
# ----------------------------------------------------------------------------------------------------
# [Formal]  kOCmMAd4l9qk6qiEaqjBjJ will not charge dayston-dead
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -gun-year-old-police-say/Q4E0zVHsV84JOdAESOCbnK/ 2017-09-26 always
# ----------------------------------------------------------------------------------------------------
# [Formal]  –gun-year-old police-say/Q4E0zVHsV84JOdAESOCbnK 2017-
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -man-shot-burglar-fleeing-his-home/MgsTnIZjXZB5u12RkvIKBN/ 2017-09-25
# ----------------------------------------------------------------------------------------------------
# [Formal]  -man shoots burglar fleeing his house... mgsTnIZjXZB5u12RkvI
#
# [Full Formal]  https://www.daytondailynews.com/sports/college/after-two close wins florida ... kOCmMAd4l9qk6qiEaqjBjJ will not charge dayston-dead ... –gun-year-old police-say/Q4E0zVHsV84JOdAESOCbnK 2017- ... -man shoots burglar fleeing his house... mgsTnIZjXZB5u12RkvI
# 2500 snippet 10

# %%
df_snippets.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_informal_snippets.tsv', 
               sep='\t', header=False, index=False)

# %%
df_snippets
# Out:
#      rank_position  ... snippet10
# 0       snes-04484  ...    filler
# 1       snes-03162  ...    filler
# 2       snes-05436  ...    filler
# 3       snes-02901  ...    filler
# 4       snes-03347  ...    filler
# ...            ...  ...       ...
# 2495    snes-00316  ...    filler
# 2496    snes-03070  ...    filler
# 2497    snes-00049  ...    filler
# 2498    snes-00836  ...    filler
# 2499    snes-04504  ...    filler
#
# [2500 rows x 11 columns]
