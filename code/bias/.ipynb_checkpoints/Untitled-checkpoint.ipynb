# %%
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('SnowballStemmer')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to /Users/weeyilee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weeyilee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading SnowballStemmer: Package 'SnowballStemmer'
# [nltk_data]     not found in index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/weeyilee/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.help.upenn_tagset('JJ.*')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...

# %%
nltk.help.upenn_tagset('RB.*')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst

# %%
import argparse
import pandas as pd
import pickle

import torch
from parameters import BERT_MODEL_PATH, CLAIM_ONLY, CLAIM_AND_EVIDENCE, EVIDENCE_ONLY, DEVICE, INPUT_TYPE_ORDER
from transformers import AdamW
import numpy as np
from utils.utils import print_message, clean_str
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
from torchnlp.word_to_vector import GloVe
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
#from hypopt import GridSearch
from model_selection import GridSearch
from tqdm import tqdm

# %%
dataset = "snes"

path = "../multi_fc_publicdata/" + dataset + "/"

main_data = pd.read_csv(path + dataset + ".tsv", sep="\t", header=None)
snippets_data = pd.read_csv(path + dataset + "_snippets.tsv", sep="\t", header=None)
label_order = pickle.load(open(path + dataset + "_labels.pkl", "rb"))
splits = pickle.load(open(path + dataset + "_index_split.pkl", "rb"))

# %%
main_data
# Out:
#               0                                                  1   \
# 0     snes-04484  Pope Francis endorsed Donald Trump for president.
# 1     snes-03162  A law firm working with Donald Trump was named...
# 2     snes-05436  McDonald's is getting rid of its "Dollar Menu"...
# 3     snes-02901  A 2016 bill before the Kentucky legislature wo...
# 4     snes-03347  Everyone with cancer has a pH that is too acidic.
# ...          ...                                                ...
# 5064  snes-04959  A photograph shows William Harley and Arthur D...
# 5065  snes-01599  Image depicts "attitude adjustment" and "smile...
# 5066  snes-02900  A cook attempted to poison George Washington b...
# 5067  snes-03298  Cavities are contagious, primarily between int...
# 5068  snes-01833  A vacationing couple staying in a foul-smellin...
#
#                 2                                                  3     4   \
# 0            false  https://www.snopes.com/fact-check/pope-francis...  None
# 1          mixture  https://www.snopes.com/fact-check/russian-law-...  None
# 2     mostly false  https://www.snopes.com/fact-check/mcdonalds-ge...  None
# 3             true  https://www.snopes.com/fact-check/kentucky-bil...  None
# 4            false  https://www.snopes.com/fact-check/everyone-who...  None
# ...            ...                                                ...   ...
# 5064         false  https://www.snopes.com/fact-check/harley-david...  None
# 5065         false  https://www.snopes.com/fact-check/1930s-housew...  None
# 5066         false       https://www.snopes.com/fact-check/red-death/  None
# 5067       mixture  https://www.snopes.com/fact-check/are-cavities...  None
# 5068          true  https://www.snopes.com/fact-check/the-bawdy-un...  None
#
#                  5     6                7     8   \
# 0         Junk News  None         Dan Evon  None
# 1       Politicians  None         Dan Evon  None
# 2          Business  None     Kim LaCapria  None
# 3          Politics  None      David Emery  None
# 4           Medical  None     Alex Kasprak  None
# ...             ...   ...              ...   ...
# 5064  Uncategorized  None         Dan Evon  None
# 5065   Fauxtography  None     Kim LaCapria  None
# 5066           Food  None  David Mikkelson  None
# 5067        Medical  None     Kim LaCapria  None
# 5068        Horrors  None  David Mikkelson  None
#
#                                                      9                 10  \
# 0     Pope Francis Shocks World, Endorses Donald Tru...      10 July 2016
# 1     Did Donald Trump Engage the ‘Russian Law Firm ...   11 January 2017
# 2            McDonald’s Getting Rid of the Dollar Menu?  29 December 2015
# 3     Kentucky Lawmaker Introduced Bill Requiring Me...  20 February 2017
# 4     Does Everyone with Cancer Have a pH That Is To...  14 December 2016
# ...                                                 ...               ...
# 5064  William Harley and Arthur Davidson Unveiling T...      4 April 2016
# 5065  Does This Image Show a 1930s Housewife Forced ...   12 October 2017
# 5066  Attempted Tomato Assassination of George Washi...   4 February 2013
# 5067                           Are Cavities Contagious?  20 December 2016
# 5068                             The Body Under the Bed      13 June 1999
#
#         11                 12
# 0     None           ['None']
# 1     None           ['None']
# 2     None           ['None']
# 3     None       ['Kentucky']
# 4     None           ['None']
# ...    ...                ...
# 5064  None           ['None']
# 5065  None  ['United_States']
# 5066  None           ['None']
# 5067  None           ['None']
# 5068  None           ['None']
#
# [5069 rows x 13 columns]

# %%
snippets_data
# Out:
#                0                                                  1   \
# 0      pomt-03627  May 8, 2013 ... Ron Maag and Kristina Roegner,...
# 1      pomt-09611  Oct 30, 2018 ... Resources ... From the start,...
# 2      pomt-06704  Says Ron Paul insisted FEMA should be shut dow...
# 3      pomt-15232  Oct 10, 2016 ... Here's everything Donald Trum...
# 4      pomt-02638  Paper from Hemp. In 1916, the U.S. Government ...
# ...           ...                                                ...
# 13576  pomt-10818  Sep 27, 2007 ... SUMMARY: A key element of the...
# 13577  pomt-08924  Scott ran for governor in 2010 on his 7-7-7 Pl...
# 13578  pomt-00146  Oct 18, 2018 ... While in Congress, he spent m...
# 13579  pomt-10701  Created to celebrate the ratification of the N...
# 13580  pomt-10435  Aug 24, 2017 ... Saudi Arabia is willing to co...
#
#                                                       2   \
# 0      Jul 10, 2018 ... Here are the top 10 states le...
# 1      Explore legal resources, campaign finance data...
# 2      All statements about Ron Paul. True. Let peopl...
# 3      Oct 9, 2016 ... Hillary Clinton and Donald Tru...
# 4      In 1916, the U.S. Government predicted that by...
# ...                                                  ...
# 13576  Roy Moore Rallies Southern Alabama Two Weeks F...
# 13577  It was called the 7-7-7 Plan: Seven Steps to 7...
# 13578  Says Ron DeSantis has not revealed $145,000 in...
# 13579  Oct 7, 2016 ... How do USCRI, Catholic Chariti...
# 13580  Find out how China got to own over $1.4 trilli...
#
#                                                       3   \
# 0      Sep 15, 2011 ... Seven of the 10 highest-unemp...
# 1      In American politics, the term swing state ref...
# 2      Aug 28, 2011 ... Ron Paul (Texas) on Sunday co...
# 3      Aug 7, 2015 ... But I will say, we have a deba...
# 4      The first crop grown in many states was hemp. ...
# ...                                                  ...
# 13576  2 days ago ... Despite numerous political figh...
# 13577  Oct 8, 2018 ... The best cure for our economic...
# 13578  Oct 25, 2018 ... In two FL governor debates, A...
# 13579  Aug 12, 2017 ... Lianne has a degree in graphi...
# 13580  Sep 1, 2017 ... Obtaining some funds in Chines...
#
#                                                       4   \
# 0      Efforts are also underway to pass RTW laws in ...
# 1      Oct 31, 2018 ... President Trump campaigns for...
# 2      Georgia residents file the most insurance clai...
# 3      Aug 7, 2015 ... Fact check: Rubio says Hillary...
# 4      In 1916, the U.S. Government predicted that by...
# ...                                                  ...
# 13576  WHERE YA GOING, MR. CONYERS? -- SPOTTED on a D...
# 13577  The 7-step economic program — over a 7-year pe...
# 13578  Oct 24, 2018 ... Ron DeSantis, left, and Talla...
# 13579  Lot Abraham Papers Correspondence, Civil War d...
# 13580  Aug 31, 2017 ... Obtaining some funds in Chine...
#
#                                                       5   \
# 0      Apr 22, 2015 ... So-called right-to-work (RTW)...
# 1      Jul 11, 2018 ... Preregistration: In Florida, ...
# 2      Jan 6, 2019 ... WASHINGTON – Amid little progr...
# 3      Jan 11, 2017 ... It's an opportunity to be her...
# 4      Jul 10, 2017 ... It was legal to pay taxes wit...
# ...                                                  ...
# 13576  Aug 4, 2017 ... Rumors have circulated for day...
# 13577  Apr 16, 2018 ... Rick Scott mostly fulfills pr...
# 13578  Oct 31, 2018 ... Gillum has not been formally ...
# 13579                                             filler
# 13580  May 16, 2016 ... Saudi Arabia's tensions with ...
#
#                                                       6   \
# 0      Oct 12, 2017 ... So-called "right to work" law...
# 1      The laws governing state primaries are complex...
# 2      Aug 31, 2011 ... Should those whose job it is ...
# 3      Jul 28, 2016 ... Transcript: Hillary Clinton's...
# 4      1850 was a peak year for Kentucky; producing 4...
# ...                                                  ...
# 13576  Doc Lee talks and votes like a conservative re...
# 13577  Jan 5, 2012 ... Rick Scott's Plan to Turn Flor...
# 13578  Oct 25, 2018 ... Ron DeSantis have spared no p...
# 13579                                             filler
# 13580  Apr 22, 2016 ... China is better for the U.S. ...
#
#                                                       7   \
# 0      In the context of US labor politics, "right-to...
# 1      Nov 4, 2018 ... Tallahassee's mayor and one of...
# 2      The political positions of Ron Paul (L-TX), Un...
# 3      Oct 9, 2016 ... Hillary Clinton and Donald Tru...
# 4      THE BENEFITS OF HEMP. In 1916, the U.S. Govern...
# ...                                                  ...
# 13576  Just a day earlier, the 90th's assistant divis...
# 13577  Oct 21, 2010 ... The details, though, are murk...
# 13578  Oct 24, 2018 ... Ron DeSantis slams Mayor Andr...
# 13579                                             filler
# 13580  Apr 20, 2016 ... Saudi Arabia is close to secu...
#
#                                                       8   \
# 0      Feb 1, 2018 ... Average hourly earnings were 2...
# 1      Sep 21, 2018 ... When we first reported that a...
# 2      Aug 29, 2011 ... The Texas Republican congress...
# 3      Jul 22, 2016 ... And that the Republican Party...
# 4      Dec 29, 2012 ... Government studies report tha...
# ...                                                  ...
# 13576  Apr 11, 2016 ... Here's a look back at some of...
# 13577  Dec 31, 2010 ... of the top job generating sta...
# 13578  Oct 24, 2018 ... Knockout kings: Andrew Gillum...
# 13579                                             filler
# 13580  Aug 24, 2017 ... SupChina's news roundup of Au...
#
#                                                       9   \
# 0      Apr 30, 2018 ... Last year, six of Ohio's 10 m...
# 1      Forms & Publications ... Early Voting Location...
# 2      Aug 28, 2011 ... (CNN) — As Hurricane Irene ba...
# 3      Feb 16, 2017 ... He's a member and has been a ...
# 4      Jun 2, 2014 ... Hemp paper was even made at Be...
# ...                                                  ...
# 13576  To all the other peoples and governments who a...
# 13577  Rick Scott has refused to provide voters with ...
# 13578  Oct 24, 2018 ... RonDeSantisFL is correct when...
# 13579                                             filler
# 13580  May 30, 2016 ... The U.S. would buy oil from S...
#
#                                                       10
# 0                                                 filler
# 1                                                 filler
# 2                                                 filler
# 3      Oct 20, 2016 ... The third and final president...
# 4      Feb 5, 2009 ... In 1916, the U.S. Government D...
# ...                                                  ...
# 13576  May 13, 2016 ... Bevin can resort to personal ...
# 13577                                             filler
# 13578                                             filler
# 13579                                             filler
# 13580  Mar 3, 2016 ... Saudi's shock loan request sig...
#
# [13581 rows x 11 columns]

# %%
label_order
# Out:
# ['false', 'mostly false', 'mixture', 'mostly true', 'true']

# %%
label_order.index('mixture')
# Out:
# 2

# %%
splits[0].shape, splits[1].shape, splits[2].shape
# Out:
# ((3548,), (507,), (1014,))

# %%
import pandas as pd

df = pd.DataFrame({'c1': [10, 11, 12], 'c2': [100, 110, 120]})

df
# Out:
#    c1   c2
# 0  10  100
# 1  11  110
# 2  12  120

# %%
import random

df['c1'] = [random.randint(3,9) for c in df['c1']]

# %%
for index, row in df.iterrows():
    df['c1'][index]=index

# %%
df
# Out:
#    c1   c2
# 0   4  100
# 1   3  110
# 2   4  120

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('SnowballStemmer')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to /Users/weeyilee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weeyilee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading SnowballStemmer: Package 'SnowballStemmer'
# [nltk_data]     not found in index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/weeyilee/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/weeyilee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocessed_stop(words):
    stopwords_list = stopwords.words('english')
    clean_words = [word for word in words if word not in stopwords_list ] 
    return (clean_words)


def preprocessed_stem(sentences):
    sno = nltk.stem.SnowballStemmer('english')
    stemmed_words = [sno.stem(word) for word in sentences]
    return stemmed_words

def preprocessed_pos(sentences):
    tags = [] #have the pos tag included
    nava_sen = []
    pt = nltk.pos_tag(sentences)

    nava = []
    nava_words = []
    for t in pt:
#        if t[1].startswith('NN') or t[1].startswith('NNS') or t[1].startswith('NNP') or t[1].startswith('NNPS') or t[1].startswith('JJ') or t[1].startswith('JJR') or t[1].startswith('JJS') or  t[1].startswith('VB') or t[1].startswith('VBG') or t[1].startswith('VBN') or t[1].startswith('VBP') or t[1].startswith('VBZ') or t[1].startswith('RB') or t[1].startswith('RBR') or t[1].startswith('RBS'):

        if t[1].startswith('NN') or t[1].startswith('NNS') or t[1].startswith('NNP') or t[1].startswith('NNPS') or t[1].startswith('JJ') or t[1].startswith('JJR') or t[1].startswith('JJS') or  t[1].startswith('VB') or t[1].startswith('VBG') or t[1].startswith('VBN') or t[1].startswith('VBP') or t[1].startswith('VBZ'):
            nava.append(t)
            nava_words.append(t[0])
    return nava_words
    
    
def find_antonym(word, word_freq):
    synonyms = set()
    antonyms = set()

    for syn in wordnet.synsets(word):   
        for l in syn.lemmas():
            synonyms.add(l.name())
            for antonym in l.antonyms():
                antonyms.add(antonym.name())
                
    antonymsL = list(antonyms)
    if len(antonymsL) != 0:
        selected = list(antonyms)[0]
        freq = 0
        for antonym in antonyms:
            if antonym in word_freq.keys():
                freqnew = int(word_freq[antonym])                
                if freqnew > freq:
                    selected = antonym
                    freq = freqnew
        return(selected)        
    
    else:
        return None

no_neg_list = ['be', 'being', 'just', 'been', 'receive', 'received', 'receiving', 'give', 'gave', 'given', 'even', 'get', 'getting', 'got', 'come', 'came', 'go', 'going', 'went', 'do', 'did', 'done', 'make', 'made', 'call', 'called', 'calling', 'face', 'buy', 'bought', 'mental', 'have', 'had', 'having', 'look', 'looked', 'looking']



def preprocessed_neg(words, word_freq):
    words_org = words.copy()
    idx = 0
    indices = []
    indices = [i for i, x in enumerate(words) if x == 'not' or x == 'never']    
    c = 0
#     print(words)
#     print(indices)
    for i in indices:
        le = len(words)
        i -= c
        
        if i >= 0 and i+1 < le : 
            if words[i+1] not in no_neg_list:
                antonym = find_antonym(words[i+1], word_freq)
                if antonym:            
                    words[i] = antonym
                    words.pop(i+1)
                    c += 1
    #                 print('***********************************')
    # if c > 0:
        
    #     print(' '.join(words_org))
    #     print(' '.join(words))
    #     print('***********************************\n\n')
        
    return (words)

steps = ['neg']

   
def preprocess(string):
    # print(f'string:\t {string} ')
    # print(steps)
    
    # add \' for negation process if needed
    # string = re.sub(r"[^A-Za-z0-9\']", " ", string)
    # per Ben's request, numeric will confuse the model; therefore, remove the numeric
    string = re.sub(r"[^A-Za-z\']", " ", string)
    string = re.sub(r"\s{2,}", " ", string)
    # retval = string.strip().lower()
    str2 = string.strip().lower()
    words= nltk.word_tokenize(str2)
    
      # Need to follow exact sequence of preprocessing steps
    
    if "neg" in steps:
        words = preprocessed_neg(words, word_freq)
    
    if "pos" in steps:
        words = preprocessed_pos(words)
    # print("pos word \n", words)
    
    if "stop" in steps:
        words = preprocessed_stop(words)
    # print("stop word \n", words)
    
    if "stem" in steps:
        words = preprocessed_stem(words)
    # print("stem word \n", words)
    
    retval = ' '.join(words)
    # print(f'Processed:\t{retval}')
    
    return retval

# %%
# %%time
filepath = 'sorted.uk.word.unigrams'  
word_freq = {}  
count = 0
with open(filepath, encoding= 'utf-8') as f:
    for line in f:
        line = line.rstrip()
        if line:
            x = line.split('\t')
            #print(x)
            #print(key, val)
            #print(str(x[1]))
            word_freq[x[1]] = str(x[0])
        count +=1
        if count > 100000:
            break

steps = ['neg']
# Out:
# CPU times: user 86.5 ms, sys: 7.98 ms, total: 94.5 ms
# Wall time: 93.2 ms

# %%
# %%time
main_data[1] = [preprocess(s) for s in main_data[1]]
main_data[1]
# Out:
# CPU times: user 1.78 s, sys: 42.6 ms, total: 1.82 s
# Wall time: 1.91 s
# 0        six out of of the highest unemployment rates a...
# 1        no democratic campaign for fla governor has ev...
# 2          says ron paul insisted fema should be shut down
# 3        says hillary clinton has been in office and in...
# 4        in the u s government predicted that by the s ...
#                                ...
# 13576    obama skips out on condemning left wing attack...
# 13577                   my step plan creates jobs in years
# 13578    says ron desantis has not revealed in receipts...
# 13579    i spend a lot of time in iowa and believe it o...
# 13580    we borrow money from the chinese to buy oil fr...
# Name: 1, Length: 13581, dtype: object

# %%
# %%time
for index, row in main_data.iterrows():
  main_data[1][index] = preprocess(row[1])
# Out:
# CPU times: user 642 ms, sys: 6.88 ms, total: 649 ms
# Wall time: 657 ms

# %%
# %%time  
for index, row in snippets_data.iterrows():
  snippets_data[1][index] = preprocess(row[1])
  snippets_data[2][index] = preprocess(row[2])
  snippets_data[3][index] = preprocess(row[3])
  snippets_data[4][index] = preprocess(row[4])
  snippets_data[5][index] = preprocess(row[5])
  snippets_data[6][index] = preprocess(row[6])
  snippets_data[7][index] = preprocess(row[7])
  snippets_data[8][index] = preprocess(row[8])
  snippets_data[9][index] = preprocess(row[9])
  snippets_data[10][index] = preprocess(row[10])
# Out:
# CPU times: user 8.77 s, sys: 56.6 ms, total: 8.82 s
# Wall time: 8.92 s
