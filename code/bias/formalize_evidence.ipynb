# %%
from google.colab import drive
import os
import sys
# !pip install transformers
drive.mount('/content/drive', force_remount=True)
sys.path.append('/content/drive/MyDrive')
print(os.getcwd())
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.1.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Mounted at /content/drive
# /content

# %%
# !pip install -r /content/drive/MyDrive/styleformer/requirements.txt
# Out:
# Obtaining styleformer from git+https://github.com/PrithivirajDamodaran/Styleformer.git#egg=styleformer (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 1))
#   Updating ./src/styleformer clone
#   Running command git fetch -q --tags
#   Running command git reset --hard -q 505ca67741d4f4e4e6f1997e3842b30e3f9a21f8
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (1.10.0+cu111)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.12.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.1.96)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.12.2)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (from styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r /content/drive/MyDrive/styleformer/requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (4.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (0.10.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->styleformer->-r /content/drive/MyDrive/styleformer/requirements.txt (line 1)) (1.1.0)
# Installing collected packages: styleformer
#   Attempting uninstall: styleformer
#     Found existing installation: styleformer 0.1
#     Can't uninstall 'styleformer'. No files were found to uninstall.
#   Running setup.py develop for styleformer
# Successfully installed styleformer-0.1

# %%
# !ls /content/drive/MyDrive/styleformer/*.py
# sys.path.append('/content/drive/MyDrive/styleformer/src/styleformer')

# %%
class Styleformer():

  def __init__(self,  style=0):
    from transformers import AutoTokenizer
    from transformers import AutoModelForSeq2SeqLM

    self.style = style
    self.adequacy = Adequacy()
    self.model_loaded = False

    if self.style == 0:
      self.ctf_tokenizer = AutoTokenizer.from_pretrained("prithivida/informal_to_formal_styletransfer")
      self.ctf_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/informal_to_formal_styletransfer")
      print("Casual to Formal model loaded...")
      self.model_loaded = True
    elif self.style == 1:
      self.ftc_tokenizer = AutoTokenizer.from_pretrained("prithivida/formal_to_informal_styletransfer")
      self.ftc_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/formal_to_informal_styletransfer")
      print("Formal to Casual model loaded...")
      self.model_loaded = True  
    elif self.style == 2:
      self.atp_tokenizer = AutoTokenizer.from_pretrained("prithivida/active_to_passive_styletransfer")
      self.atp_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/active_to_passive_styletransfer")
      print("Active to Passive model loaded...")  
      self.model_loaded = True
    elif self.style == 3:
      self.pta_tokenizer = AutoTokenizer.from_pretrained("prithivida/passive_to_active_styletransfer")
      self.pta_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/passive_to_active_styletransfer")
      print("Passive to Active model loaded...")        
      self.model_loaded = True
    else:
      print("Only CTF, FTC, ATP and PTA are supported in the pre-release...stay tuned")

  def transfer(self, input_sentence, inference_on=0, quality_filter=0.95, max_candidates=5):
      if self.model_loaded:
        if inference_on == 0:
          device = "cpu"
        elif inference_on == 1:
          device = "cuda:0"  
        else:  
          device = "cpu"
          print("Onnx + Quantisation is not supported in the pre-release...stay tuned.")

        if self.style == 0:
          output_sentence = self._casual_to_formal(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 1:
          output_sentence = self._formal_to_casual(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 2:
          output_sentence = self._active_to_passive(input_sentence, device)
          return output_sentence        
        elif self.style == 3:
          output_sentence = self._passive_to_active(input_sentence, device)
          return output_sentence           
      else:
        print("Models aren't loaded for this style, please use the right style during init")  


  def _formal_to_casual(self, input_sentence, device, quality_filter, max_candidates):
      ftc_prefix = "transfer Formal to Casual: "
      src_sentence = input_sentence
      input_sentence = ftc_prefix + input_sentence
      input_ids = self.ftc_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ftc_model = self.ftc_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ftc_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ftc_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _casual_to_formal(self, input_sentence, device, quality_filter, max_candidates):
      ctf_prefix = "transfer Casual to Formal: "
      src_sentence = input_sentence
      input_sentence = ctf_prefix + input_sentence
      input_ids = self.ctf_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ctf_model = self.ctf_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ctf_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ctf_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _active_to_passive(self, input_sentence, device):
      atp_prefix = "transfer Active to Passive: "
      src_sentence = input_sentence
      input_sentence = atp_prefix + input_sentence
      input_ids = self.atp_tokenizer.encode(input_sentence, return_tensors='pt')
      self.atp_model = self.atp_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.atp_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.atp_tokenizer.decode(preds[0], skip_special_tokens=True).strip()

  def _passive_to_active(self, input_sentence, device):
      pta_prefix = "transfer Passive to Active: "
      src_sentence = input_sentence
      input_sentence = pta_prefix + input_sentence
      input_ids = self.pta_tokenizer.encode(input_sentence, return_tensors='pt')
      self.pta_model = self.pta_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.pta_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.pta_tokenizer.decode(preds[0], skip_special_tokens=True).strip()      

    
class Adequacy():

  def __init__(self, model_tag='prithivida/parrot_adequacy_on_BART'):
    from transformers import AutoModelForSequenceClassification, AutoTokenizer
    self.nli_model = AutoModelForSequenceClassification.from_pretrained(model_tag)
    self.tokenizer = AutoTokenizer.from_pretrained(model_tag)
    
  def filter(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      top_adequacy_phrases = []
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
            top_adequacy_phrases.append(para_phrase)
      return top_adequacy_phrases

  def score(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      adequacy_scores = {}
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
          adequacy_scores[para_phrase] = adequacy_score
      return adequacy_scores

# %%
# !nvidia-smi
# Out:
# Wed Dec  1 06:34:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    40W / 300W |   4313MiB / 16160MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import warnings
import transformers
import re
warnings.filterwarnings("ignore")
import pandas as pd
import os

sf = Styleformer(style = 0)

snes_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes.tsv"
snes_snippets_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes_snippets.tsv"

snes_col_list = ["claimID", "claim", "label", "claimURL", "reason", "categories", "speaker",
                 "checker", "tags", "articleTitle", "publishDate", "claimDate", "entities"]
df_snes = pd.read_csv(snes_path, sep='\t', names=snes_col_list, index_col=False)

snes_snippets_col_list = ["rank_position", "snippet1", "snippet2", "snippet3", "snippet4", 
                 "snippet5", "snippet6", "snippet7", "snippet8", "snippet9", "snippet10"]
df_snippets = pd.read_csv(snes_snippets_path, sep='\t', names=snes_snippets_col_list, index_col=False)

# %%
df_snippets.iloc[0]['snippet1']
# Out:
# 'Oct 24, 2016 ... Q: Did Pope Francis endorse Donald Trump? ... “Pope Francis Shocks World,  Endorses Donald Trump for President, Releases Statement.'

# %%
def get_formal_snippet(snippet):
  snippet = snippet.strip()
  if snippet == 'filler' or snippet == '':
    return snippet
  full_target = ""  
  split_sentences = re.split(r'\.\.\.+', snippet)
  for split_sentence in split_sentences:
    if split_sentence.strip() != '':
      target_sentence = sf.transfer(split_sentence, inference_on=1)
      print("-" *100)
      print("[Casual] ", split_sentence)
      print("-" *100)
      if target_sentence is not None:
          print("[Formal] ",target_sentence)
          print()
          if full_target != "":
            full_target += " ... " + target_sentence
          else:
            full_target += target_sentence
      else:
          print("No good quality transfers available !")
  print("[Full Formal] ", full_target)
  return full_target

for index, row in df_snippets.iterrows():
  print(str(index+1) + " snippet 1")
  df_snippets.at[index, 'snippet1'] = get_formal_snippet(row['snippet1'])
  print(str(index+1) + " snippet 2")
  df_snippets.at[index, 'snippet2'] = get_formal_snippet(row['snippet2'])
  print(str(index+1) + " snippet 3")
  df_snippets.at[index, 'snippet3'] = get_formal_snippet(row['snippet3'])
  print(str(index+1) + " snippet 4")
  df_snippets.at[index, 'snippet4'] = get_formal_snippet(row['snippet4'])
  print(str(index+1) + " snippet 5")
  df_snippets.at[index, 'snippet5'] = get_formal_snippet(row['snippet5'])
  print(str(index+1) + " snippet 6")
  df_snippets.at[index, 'snippet6'] = get_formal_snippet(row['snippet6'])
  print(str(index+1) + " snippet 7")    
  df_snippets.at[index, 'snippet7'] = get_formal_snippet(row['snippet7'])
  print(str(index+1) + " snippet 8")
  df_snippets.at[index, 'snippet8'] = get_formal_snippet(row['snippet8']) 
  print(str(index+1) + " snippet 9")
  df_snippets.at[index, 'snippet9'] = get_formal_snippet(row['snippet9']) 
  print(str(index+1) + " snippet 10")
  df_snippets.at[index, 'snippet10'] = get_formal_snippet(row['snippet10']) 

df_snippets.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_formal_snippets.tsv', 
               sep='\t', header=False, index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# [Casual]   them from a  bunker less than two miles from the White House.
# ----------------------------------------------------------------------------------------------------
# [Formal]  They are from a bunker less than two miles from the White House.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Around The Web.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is around the internet.
#
# [Full Formal]  The date is February 11, 2017. ... When Barack Obama stated he was emotional by antiTrump protests, he was sending a message of approval to his troops. ... Obama has an army of more than 30,000 agitators. ... They are from a bunker less than two miles from the White House. ... It is around the internet.
# 2475 snippet 2
# ----------------------------------------------------------------------------------------------------
# [Casual]  Feb 13, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  February 13, 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Throughout American history, most ex-presidents have chosen to move
# ----------------------------------------------------------------------------------------------------
# [Formal]  Most of our past presidents have made the move.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   His  new home is less than two miles from the White House, and from
# ----------------------------------------------------------------------------------------------------
# [Formal]  His new home is less than two miles from the White House.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   in many of the  protests and riots that have been popping up around the
# ----------------------------------------------------------------------------------------------------
# [Formal]  In many of the protests and riots that have been popping up around the world.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   When former  President Barack Obama said he was “heartened” by anti-Trump protests,
# ----------------------------------------------------------------------------------------------------
# [Formal]  When former President Barack Obama said he was “heartened” by antiTrump protests, he said yes
#
# [Full Formal]  February 13, 2017. ... Most of our past presidents have made the move. ... His new home is less than two miles from the White House. ... In many of the protests and riots that have been popping up around the world. ... When former President Barack Obama said he was “heartened” by antiTrump protests, he said yes
# 2475 snippet 3
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 6, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date of this event is August 6, 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Organizing for Action, a hub of the Democratic protest movement,
# ----------------------------------------------------------------------------------------------------
# [Formal]  Organizing for Action is a hub of the Democratic Protest movement.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Then- President Barack Obama speaks during an Organizing for Action
# ----------------------------------------------------------------------------------------------------
# [Formal]  President Barack Obama speaks at an event titled Organizing for Action.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   for its next  showdown this fall — battling President Donald Trump's
# ----------------------------------------------------------------------------------------------------
# [Formal]  The next challenge to Donald Trump will be in the fall.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   “Our members are  home.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Our members are at home.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   while he was in the White House, OFA returned it to him in January.
# ----------------------------------------------------------------------------------------------------
# [Formal]  

#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Discover ideas about Clint Eastwood Kids
# ----------------------------------------------------------------------------------------------------
# [Formal]  Get ideas about Clint Eastwood.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   But the one they hate, invade and terrorise are.
# ----------------------------------------------------------------------------------------------------
# [Formal]  That one they hate, invade and terrorise are.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Something feminists should  learn.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is something that feminists should learn.
#
# [Full Formal]  I would like if America were more concerned with offending God and less. ... Please consider other people's opinions. ... Get ideas about Clint Eastwood. ... That one they hate, invade and terrorise are. ... It is something that feminists should learn.
# 2476 snippet 4
# ----------------------------------------------------------------------------------------------------
# [Casual]  Hopefully, more and more people will begin to feel their story is somehow part of
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is hoped that more and more people will begin to feel that their story is somehow part of something larger.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   It allows us to say that those whose health care or tuition may rise faster than
# ----------------------------------------------------------------------------------------------------
# [Formal]  It allows us to say that those whose health care or tuition may rise faster than others.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   regard for each other, the idea that everybody has a stake in the country, that
# ----------------------------------------------------------------------------------------------------
# [Formal]  Respect for each other, the idea that everyone has a stake in the country.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   in my faith in God and my faith in the American people - that working together
# ----------------------------------------------------------------------------------------------------
# [Formal]  My faith in God and my faith in the American people, that we should work together.
#
# [Full Formal]  It is hoped that more and more people will begin to feel that their story is somehow part of something larger. ... It allows us to say that those whose health care or tuition may rise faster than others. ... Respect for each other, the idea that everyone has a stake in the country. ... My faith in God and my faith in the American people, that we should work together.
# 2476 snippet 5
# ----------------------------------------------------------------------------------------------------
# [Casual]  Dec 7, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date is December 7, 2018.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Have you ever heard some other lyrics? From say…
# ----------------------------------------------------------------------------------------------------
# [Formal]  Are you familiar with any other lyrics?
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Now the song – baby it's  cold outside is offensive
# ----------------------------------------------------------------------------------------------------
# [Formal]  That song called, Baby it's Cold Outside, is offensive.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Clint Eastwood once said, “I wish America was more  concerned about offending God and less concerned about offending people.”
# ----------------------------------------------------------------------------------------------------
# [Formal]  Clint Eastwood once stated, I wish America was more concerned about offending God and less concerned about offending people.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   I  should not have to start or end a statement with “no offense.
# ----------------------------------------------------------------------------------------------------
# [Formal]  I do not need to begin or end a statement with, 'no offense.'
#
# [Full Formal]  The date is December 7, 2018. ... Are you familiar with any other lyrics? ... That song called, Baby it's Cold Outside, is offensive. ... Clint Eastwood once stated, I wish America was more concerned about offending God and less concerned about offending people. ... I do not need to begin or end a statement with, 'no offense.'
# 2476 snippet 6
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jan 27, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date is Jan 27, 2017.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   It's less likely to drop or break; it will open in your mouth.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is less likely to fall or break, it will open in your mouth.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   prefers to pair sushi  with a dry sake and says if you're more interested in wine,
# ----------------------------------------------------------------------------------------------------
# [Formal]  I prefer to pair sushi with an alcoholic drink. If you prefer a wine, please get that.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   The Ume Matsu is a  selection of five different fish served sashimi
# ----------------------------------------------------------------------------------------------------
# [Formal]  Sashimi is a selection of five different fish served in the Ume Matsu.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   David Eastwood says
# ----------------------------------------------------------------------------------------------------
# [Formal]  According to David Eastwood
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   My  suggestion, if you are concerned about offending the chef, pick a nice
# ----------------------------------------------------------------------------------------------------
# [Formal]  Pick a nice one if you are concerned about irritating the chef.
#
# [Full Formal]  The date is Jan 27, 2017. ... It is less likely to fall or break, it will open in your mouth. ... I prefer to pair sushi with an alcoholic drink. If you prefer a wine, please get that. ... Sashimi is a selection of five different fish served in the Ume Matsu. ... According to David Eastwood ... Pick a nice one if you are concerned about irritating the chef.
# 2476 snippet 7
# ----------------------------------------------------------------------------------------------------
# [Casual]  Feb 8, 2013
# ----------------------------------------------------------------------------------------------------
# [Formal]  This message was posted on February 8, 2013.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Since his death, a few reporters have heard trickles of other stories.
# ----------------------------------------------------------------------------------------------------
# [Formal]  After he passed away, a few reporters have heard other stories.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Then he  turned slightly and fired twice more, hitting the second man twice in
# ----------------------------------------------------------------------------------------------------
# [Formal]  Then, he turned slightly and fired twice more, hitting the second man twice in the process.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   He said the  officers were very understanding, that they didn't want to
# ----------------------------------------------------------------------------------------------------
# [Formal]  He said that the officers were very understanding and that they did not want to.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   In every sense of the  word, Chris Kyle was a true American badass.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Chris Kyle was truly American.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Scott shauger.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Scott Schauger.
#
# [Full Formal]  This message was posted on February 8, 2013. ... After he passed away, a few reporters have heard other stories. ... Then, he turned slightly and fired twice more, hitting the second man twice in the process. ... He said that the officers were very understanding and that they did not want to. ... Chris Kyle was truly American. ... Scott Schauger.
# 2476 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  Jackson Katz: There's the America that recoils in horror whenever a brutal mass
# ----------------------------------------------------------------------------------------------------
# [Formal]  Jackson Katz said, There is America that recoils in horror whenever a brutal mass
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Panelist: One thing we can say for certain is that men are more violent than  women.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Men are more violent than women, we can be sure.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   mental health care, and addressing a culture that too often glorifies  guns and
# ----------------------------------------------------------------------------------------------------
# [Formal]  Mental health care. Addressing a culture that often glorifies guns and guns.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Clint Eastwood: You don't just come in and insult a man in his own  shop.
# ----------------------------------------------------------------------------------------------------
# [Formal]  Clint Eastwood says to not just come in and insult a man in his own shop.
#
# [Full Formal]  Jackson Katz said, There is America that recoils in horror whenever a brutal mass ... Men are more violent than women, we can be sure. ... Mental health care. Addressing a culture that often glorifies guns and guns. ... Clint Eastwood says to not just come in and insult a man in his own shop.
# 2476 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]  Mar 20, 2013
# ----------------------------------------------------------------------------------------------------
# [Formal]  Mar 20, 2013.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   In other words, the invented cowboy tradition is part of the rise of both
# ----------------------------------------------------------------------------------------------------
# [Formal]  The invented cowboy tradition is part of the rise of both, in other words.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   On the  contrary, practically all the westerns that any of us would wish to see again
# ----------------------------------------------------------------------------------------------------
# [Formal]  Almost all of the westerns we would like to see again.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    What is more, once the late western movie had itself become infected
# ----------------------------------------------------------------------------------------------------
# [Formal]  It had become infected once the movie had run late.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   but who  doesn't know what he's doing or doesn't care except about ripping
# ----------------------------------------------------------------------------------------------------
# [Formal]  Who does not know what he is doing, or does not care, except about ripping.
#
# [Full Formal]  Mar 20, 2013. ... The invented cowboy tradition is part of the rise of both, in other words. ... Almost all of the westerns we would like to see again. ... It had become infected once the movie had run late. ... Who does not know what he is doing, or does not care, except about ripping.
# 2476 snippet 10
# 2477 snippet 1
# ----------------------------------------------------------------------------------------------------
# [Casual]  Dec 7, 2015
# ----------------------------------------------------------------------------------------------------
# [Formal]  On Dec 7th, 2015.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Rumors, such as the one that Arby's serves "liquid meat," have
# ----------------------------------------------------------------------------------------------------
# [Formal]  Rumors have spread that Arby's serves Liquid Meat.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   at how the  sausage — or roast beef — gets made at Arby's new Manhattan location. 1/9
# ----------------------------------------------------------------------------------------------------
# [Formal]  At how the sausage is prepared at Arby's new Manhattan location.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    The sandwich is topped with mayonnaise and BBQ sauce, but not the
# ----------------------------------------------------------------------------------------------------
# [Formal]  The sandwich is topped with mayonnaise and BBQ sauce but not the sauce.
#
# [Full Formal]  On Dec 7th, 2015. ... Rumors have spread that Arby's serves Liquid Meat. ... At how the sausage is prepared at Arby's new Manhattan location. ... The sandwich is topped with mayonnaise and BBQ sauce but not the sauce.
# 2477 snippet 2
# ----------------------------------------------------------------------------------------------------
# [Casual]  I will tell you how to make a roast beef that is much better than Arbys.
# ----------------------------------------------------------------------------------------------------
# [Formal]  I will explain how to make a roast beef that is much better than Arbys.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   I'd  recommend grinding some lean beef to a paste, blend in powdered garlic, onion,  salt,
# ----------------------------------------------------------------------------------------------------
# [Formal]  I would recommend grinding some lean beef to a paste and blend in powdered garlic, onion, and salt.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Perform a quick dip in a hot liquid, I usually prefer stock but you can get by  with
# ----------------------------------------------------------------------------------------------------
# [Formal]  Usually you can get by with stock but you can do it by simply dipping in hot liquid.
#
# [Full Formal]  I will explain how to make a roast beef that is much better than Arbys. ... I would recommend grinding some lean beef to a paste and blend in powdered garlic, onion, and salt. ... Usually you can get by with stock but you can do it by simply dipping in hot liquid.
# 2477 snippet 3
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 23, 2007
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date is August 23, 2007.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Arby's roast beef is not made from some sort of meat-flavoured congealed gel. I  think, just my own
# ----------------------------------------------------------------------------------------------------
# [Formal]  Arby's roast beef is not made from an 'expensive' type of congealed gel I believe, it is my own
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Second, until I can see with my own eyes the Arby's roast  beef being made I stand by the Slurry, Gelatin and who knows what else. a.  ariluv230
# ----------------------------------------------------------------------------------------------------
# [Formal]  Secondly, until I can see with my own eyes the Arby's roast beef being made, I stand by the slurry, gelatin
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   With the seasoned coating, and dipped in Heinz bbq sauce.
# ----------------------------------------------------------------------------------------------------
# [Formal]  It was coated with a seasoned coating, then dip in Heinz Bbq Sauce.
#
# [Full Formal]  The date is August 23, 2007. ... Arby's roast beef is not made from an 'expensive' type of congealed gel I believe, it is my own ... Secondly, until I can see with my own eyes the Arby's roast beef being made, I stand by the slurry, gelatin ... It was coated with a seasoned coating, then dip in Heinz Bbq Sauce.
# 2477 snippet 4
# ----------------------------------------------------------------------------------------------------
# [Casual]  Arby's "rost beef" is emulsified beef, reformed with meat glue. That's how they can  get product consistency. Think of it as hot dogs sliced thin. Ahhh, yes, sources.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The 'rost beef' from Arby is emulsified beef reformed with meat glue. It is similar to hot dogs
#
# [Full Formal]  The 'rost beef' from Arby is emulsified beef reformed with meat glue. It is similar to hot dogs
# 2477 snippet 5
# ----------------------------------------------------------------------------------------------------
# [Casual]  Aug 26, 2016
# ----------------------------------------------------------------------------------------------------
# [Formal]  August 26, 2016.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Another claim says that Arby's roast beef is made from a paste, gel, powder or  liquid. Again, this one is false, according to internet myth buster
# ----------------------------------------------------------------------------------------------------
# [Formal]  Another claim states that Arby's roast beef is made from a paste, gel, powder or liquid. Again, this one is false according to
#
# [Full Formal]  August 26, 2016. ... Another claim states that Arby's roast beef is made from a paste, gel, powder or liquid. Again, this one is false according to
# 2477 snippet 6
# ----------------------------------------------------------------------------------------------------
# [Casual]  Oct 4, 2018
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date is October 4, 2018.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Myth: Chicken McNuggets are made with pink slime. Chicken nuggets
# ----------------------------------------------------------------------------------------------------
# [Formal]  Myth is that chicken nuggets are made from pink slime.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Myth:  Arby's uses “liquid meat”
# ----------------------------------------------------------------------------------------------------
# [Formal]  Myth that Arby's uses liquid meat.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   The claim is the beef is a reconstituted liquid, gel,  powder, or paste. While it's true their roast beef sandwiches are weirdly uniform,  the company has posted plenty of videos of their roasts being sliced.
# ----------------------------------------------------------------------------------------------------
# [Formal]  The company claims that their beef can be reconstituted liquid, gel, powder, or paste. While it is true that their roast beef sandwiches are weird
#
# [Full Formal]  The date is October 4, 2018. ... Myth is that chicken nuggets are made from pink slime. ... Myth that Arby's uses liquid meat. ... The company claims that their beef can be reconstituted liquid, gel, powder, or paste. While it is true that their roast beef sandwiches are weird
# 2477 snippet 7
# ----------------------------------------------------------------------------------------------------
# [Casual]  Mar 28, 2015
# ----------------------------------------------------------------------------------------------------
# [Formal]  Posted on the 28th of Mar 2015.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Arby's Roast Beef. John S. Loading
# ----------------------------------------------------------------------------------------------------
# [Formal]  John S. Loading. He recommends Arby's Roast Beef.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Unsubscribe from John S? Cancel  Unsubscribe. Working
# ----------------------------------------------------------------------------------------------------
# [Formal]  Cancel unsubscribe from John S.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   SubscribeSubscribedUnsubscribe 127.
# ----------------------------------------------------------------------------------------------------
# [Formal]  This can be subscribed, subscribed or unsubscribed.
#
# [Full Formal]  Posted on the 28th of Mar 2015. ... John S. Loading. He recommends Arby's Roast Beef. ... Cancel unsubscribe from John S. ... This can be subscribed, subscribed or unsubscribed.
# 2477 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  Oct 10, 2017
# ----------------------------------------------------------------------------------------------------
# [Formal]  The date is Oct 10, 2017.
#
# ...
# ----------------------------------------------------------------------------------------------------
# [Formal]  A cop shot a two year old black baby after mistaken pacifier for gun.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]

#
# ----------------------------------------------------------------------------------------------------
# [Casual]   Josie Gibson EXCLUSIVE 'I didn't want to be another statistic':
# ----------------------------------------------------------------------------------------------------
# [Formal]  Josie Gibson exclaimed, 'I did not want to be another statistic.'
#
# [Full Formal]  On the second of March, 2016. ... As someone who has had a penis for 30 years, I am more comfortable with that. ... In September 2012, a twoweek old infant died at a Brooklyn hospital after contracting herpes. ... Ironically, his death coincided with International Women's Day. ... Josie Gibson exclaimed, 'I did not want to be another statistic.'
# 2500 snippet 8
# ----------------------------------------------------------------------------------------------------
# [Casual]  the of to a and in that is for on it with as was he his but at are be by have from has
# ----------------------------------------------------------------------------------------------------
# [Formal]  It is for on it with as was he his, but at are be by have from has.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   just into years now most after even do last over first other year could also two
# ----------------------------------------------------------------------------------------------------
# [Formal]  This is in years that most are going to last over the first year, and can even be two years
#
# ----------------------------------------------------------------------------------------------------
# [Casual]    th isnt yearold started close report talk began team move george together room
# ----------------------------------------------------------------------------------------------------
# [Formal]  The is not yearold started close report talk began team move George together room.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   familiar illegal peter arab murder planned airline officers drugs features twice
# ----------------------------------------------------------------------------------------------------
# [Formal]  Probably familiar because of its illegality. Peridas murder planned for airline officers and drug screens twice.
#
# [Full Formal]  It is for on it with as was he his, but at are be by have from has. ... This is in years that most are going to last over the first year, and can even be two years ... The is not yearold started close report talk began team move George together room. ... Probably familiar because of its illegality. Peridas murder planned for airline officers and drug screens twice.
# 2500 snippet 9
# ----------------------------------------------------------------------------------------------------
# [Casual]   https://www.daytondailynews.com/sports/college/after-two-close-wins-florida-
# ----------------------------------------------------------------------------------------------------
# [Formal]  The link is to https://www.daytondailynews.com/sports/college/after-two-close-wins
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -will-not-pursue-charges-dayton-dead-dog-case/kOCmMAd4l9qk6qiEaqjBjJ/
# ----------------------------------------------------------------------------------------------------
# [Formal]  I do not want to charge Daytone for a dead dog case.
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -gun-year-old-police-say/Q4E0zVHsV84JOdAESOCbnK/ 2017-09-26 always
# ----------------------------------------------------------------------------------------------------
# [Formal]  That is always on the website Gun Years Old Police, you can get it from the website Q4E0zVHsV84JOdA
#
# ----------------------------------------------------------------------------------------------------
# [Casual]   -man-shot-burglar-fleeing-his-home/MgsTnIZjXZB5u12RkvIKBN/ 2017-09-25
# ----------------------------------------------------------------------------------------------------
# [Formal]  Man shot burglar fleeing his home https://mgstnIZjXZB5u12RkvIKBN/ 2017
#
# [Full Formal]  The link is to https://www.daytondailynews.com/sports/college/after-two-close-wins ... I do not want to charge Daytone for a dead dog case. ... That is always on the website Gun Years Old Police, you can get it from the website Q4E0zVHsV84JOdA ... Man shot burglar fleeing his home https://mgstnIZjXZB5u12RkvIKBN/ 2017
# 2500 snippet 10

# %%
df_snippets.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_formal_snippets.tsv', 
               sep='\t', header=False, index=False)

# %%
df_snippets
# Out:
#      rank_position  ... snippet10
# 0       snes-04484  ...    filler
# 1       snes-03162  ...    filler
# 2       snes-05436  ...    filler
# 3       snes-02901  ...    filler
# 4       snes-03347  ...    filler
# ...            ...  ...       ...
# 2495    snes-00316  ...    filler
# 2496    snes-03070  ...    filler
# 2497    snes-00049  ...    filler
# 2498    snes-00836  ...    filler
# 2499    snes-04504  ...    filler
#
# [2500 rows x 11 columns]
