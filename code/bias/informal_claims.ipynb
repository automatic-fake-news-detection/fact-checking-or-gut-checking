# %%
# This code uses the styleformer library to recreate the snopes dataset with formalized text. 
# Change the style_transfer_type integer to choose what kind of style transfer you wish
# 0 for informal to formal, 1 for formal to informal, 2 for active to passive, 3 for passive to active

style_transfer_type = 1

from google.colab import drive
import os
import sys
# !pip install transformers
drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive')
print(os.getcwd())
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 5.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 38.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 480 kB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 35.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 45.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5
# Mounted at /content/drive
# /content

# %%
# !pip install -r /content/drive/MyDrive/styleformer/requirements.txt

# %%
class Styleformer():

  def __init__(self,  style=0):
    from transformers import AutoTokenizer
    from transformers import AutoModelForSeq2SeqLM

    self.style = style
    self.adequacy = Adequacy()
    self.model_loaded = False

    if self.style == 0:
      self.ctf_tokenizer = AutoTokenizer.from_pretrained("prithivida/informal_to_formal_styletransfer")
      self.ctf_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/informal_to_formal_styletransfer")
      print("Casual to Formal model loaded...")
      self.model_loaded = True
    elif self.style == 1:
      self.ftc_tokenizer = AutoTokenizer.from_pretrained("prithivida/formal_to_informal_styletransfer")
      self.ftc_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/formal_to_informal_styletransfer")
      print("Formal to Casual model loaded...")
      self.model_loaded = True  
    elif self.style == 2:
      self.atp_tokenizer = AutoTokenizer.from_pretrained("prithivida/active_to_passive_styletransfer")
      self.atp_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/active_to_passive_styletransfer")
      print("Active to Passive model loaded...")  
      self.model_loaded = True
    elif self.style == 3:
      self.pta_tokenizer = AutoTokenizer.from_pretrained("prithivida/passive_to_active_styletransfer")
      self.pta_model = AutoModelForSeq2SeqLM.from_pretrained("prithivida/passive_to_active_styletransfer")
      print("Passive to Active model loaded...")        
      self.model_loaded = True
    else:
      print("Only CTF, FTC, ATP and PTA are supported in the pre-release...stay tuned")

  def transfer(self, input_sentence, inference_on=0, quality_filter=0.95, max_candidates=5):
      if self.model_loaded:
        if inference_on == 0:
          device = "cpu"
        elif inference_on == 1:
          device = "cuda:0"  
        else:  
          device = "cpu"
          print("Onnx + Quantisation is not supported in the pre-release...stay tuned.")

        if self.style == 0:
          output_sentence = self._casual_to_formal(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 1:
          output_sentence = self._formal_to_casual(input_sentence, device, quality_filter, max_candidates)
          return output_sentence
        elif self.style == 2:
          output_sentence = self._active_to_passive(input_sentence, device)
          return output_sentence        
        elif self.style == 3:
          output_sentence = self._passive_to_active(input_sentence, device)
          return output_sentence           
      else:
        print("Models aren't loaded for this style, please use the right style during init")  


  def _formal_to_casual(self, input_sentence, device, quality_filter, max_candidates):
      ftc_prefix = "transfer Formal to Casual: "
      src_sentence = input_sentence
      input_sentence = ftc_prefix + input_sentence
      input_ids = self.ftc_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ftc_model = self.ftc_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ftc_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ftc_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _casual_to_formal(self, input_sentence, device, quality_filter, max_candidates):
      ctf_prefix = "transfer Casual to Formal: "
      src_sentence = input_sentence
      input_sentence = ctf_prefix + input_sentence
      input_ids = self.ctf_tokenizer.encode(input_sentence, return_tensors='pt')
      self.ctf_model = self.ctf_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.ctf_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=max_candidates)
     
      gen_sentences = set()
      for pred in preds:
        gen_sentences.add(self.ctf_tokenizer.decode(pred, skip_special_tokens=True).strip())

      adequacy_scored_phrases = self.adequacy.score(src_sentence, list(gen_sentences), quality_filter, device)
      ranked_sentences = sorted(adequacy_scored_phrases.items(), key = lambda x:x[1], reverse=True)
      if len(ranked_sentences) > 0:
        return ranked_sentences[0][0]
      else:
        return None

  def _active_to_passive(self, input_sentence, device):
      atp_prefix = "transfer Active to Passive: "
      src_sentence = input_sentence
      input_sentence = atp_prefix + input_sentence
      input_ids = self.atp_tokenizer.encode(input_sentence, return_tensors='pt')
      self.atp_model = self.atp_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.atp_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.atp_tokenizer.decode(preds[0], skip_special_tokens=True).strip()

  def _passive_to_active(self, input_sentence, device):
      pta_prefix = "transfer Passive to Active: "
      src_sentence = input_sentence
      input_sentence = pta_prefix + input_sentence
      input_ids = self.pta_tokenizer.encode(input_sentence, return_tensors='pt')
      self.pta_model = self.pta_model.to(device)
      input_ids = input_ids.to(device)
      
      preds = self.pta_model.generate(
          input_ids,
          do_sample=True, 
          max_length=32, 
          top_k=50, 
          top_p=0.95, 
          early_stopping=True,
          num_return_sequences=1)
     
      return self.pta_tokenizer.decode(preds[0], skip_special_tokens=True).strip()      

    
class Adequacy():

  def __init__(self, model_tag='prithivida/parrot_adequacy_on_BART'):
    from transformers import AutoModelForSequenceClassification, AutoTokenizer
    self.nli_model = AutoModelForSequenceClassification.from_pretrained(model_tag)
    self.tokenizer = AutoTokenizer.from_pretrained(model_tag)
    
  def filter(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      top_adequacy_phrases = []
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
            top_adequacy_phrases.append(para_phrase)
      return top_adequacy_phrases

  def score(self, input_phrase, para_phrases, adequacy_threshold, device="cpu"):
      adequacy_scores = {}
      for para_phrase in para_phrases:
        x = self.tokenizer.encode(input_phrase, para_phrase, return_tensors='pt',truncation_strategy='only_first')
        self.nli_model = self.nli_model.to(device)
        logits = self.nli_model(x.to(device))[0]
        # we throw away "neutral" (dim 1) and take the probability of "entailment" (2) as the adequacy score
        entail_contradiction_logits = logits[:,[0,2]]
        probs = entail_contradiction_logits.softmax(dim=1)
        prob_label_is_true = probs[:,1]
        adequacy_score = prob_label_is_true[0].item()
        if adequacy_score >= adequacy_threshold:
          adequacy_scores[para_phrase] = adequacy_score
      return adequacy_scores

# %%
# !nvidia-smi
# Out:
# Mon Dec  6 16:11:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import os
import torch
import warnings
import transformers
import re
warnings.filterwarnings("ignore")

sf = Styleformer(style = style_transfer_type)

snes_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes.tsv"
snes_snippets_path = "/content/drive/MyDrive/Deep Learning NLP/paper/snes_snippets.tsv"

snes_col_list = ["claimID", "claim", "label", "claimURL", "reason", "categories", "speaker",
                 "checker", "tags", "articleTitle", "publishDate", "claimDate", "entities"]
df_snes = pd.read_csv(snes_path, sep='\t', names=snes_col_list, index_col=False)

snes_snippets_col_list = ["rank_position", "snippet1", "snippet2", "snippet3", "snippet4", 
                 "snippet5", "snippet6", "snippet7", "snippet8", "snippet9", "snippet10"]
df_snippets = pd.read_csv(snes_snippets_path, sep='\t', names=snes_snippets_col_list, index_col=False)
# Out:
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Formal to Casual model loaded...

# %%
df_snes
# Out:
#          claimID  ...           entities
# 0     snes-04484  ...           ['None']
# 1     snes-03162  ...           ['None']
# 2     snes-05436  ...           ['None']
# 3     snes-02901  ...       ['Kentucky']
# 4     snes-03347  ...           ['None']
# ...          ...  ...                ...
# 5064  snes-04959  ...           ['None']
# 5065  snes-01599  ...  ['United_States']
# 5066  snes-02900  ...           ['None']
# 5067  snes-03298  ...           ['None']
# 5068  snes-01833  ...           ['None']
#
# [5069 rows x 13 columns]

# %%
for index, row in df_snes.iterrows():
  full_target = ""  
  split_sentences = re.split(r'\.\.\.+', row['claim'])
  for split_sentence in split_sentences:
    target_sentence = sf.transfer(split_sentence, inference_on=1)
    print("-" *100)
    print("[Original] ", split_sentence)
    print("-" *100)
    if target_sentence is not None:
        print("[Informal] ",target_sentence)
        print()
        if full_target != "":
          full_target += " ... " + target_sentence
        else:
          full_target += target_sentence
    else:
        print("No good quality transfers available !")
  print("[Full Informal] ", full_target)
  print(str(index+1) + ": " + row['claim'])
  df_snes.at[index, 'claim'] = full_target
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------------------------------------------------------------------------
# [Original]  The Trump International Hotel in Washington D.C. handed out flyers promoting an anti-CNN petition to guests at check-in.
# ----------------------------------------------------------------------------------------------------
# [Informal]  at check in the Trump International Hotel in Washington D.C. distributed flyers on the anticnn petition.
#
# [Full Informal]  at check in the Trump International Hotel in Washington D.C. distributed flyers on the anticnn petition.
# 4356: The Trump International Hotel in Washington D.C. handed out flyers promoting an anti-CNN petition to guests at check-in.
# ----------------------------------------------------------------------------------------------------
# [Original]  Rihanna was barred from entering Senegal on the grounds that she was suspected of being part of the Illuminati.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Rihanna was banned from entering Senegal due to suspicion she was part of the Illuminati.
#
# [Full Informal]  Rihanna was banned from entering Senegal due to suspicion she was part of the Illuminati.
# 4357: Rihanna was barred from entering Senegal on the grounds that she was suspected of being part of the Illuminati.
# ----------------------------------------------------------------------------------------------------
# [Original]  In July 2016, Massachusetts implemented a new ban on the sale of all semi-automatic rifles.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Massachusetts adduced a ban on selling semiautomatic rifles in July 2016.
#
# [Full Informal]  Massachusetts adduced a ban on selling semiautomatic rifles in July 2016.
# 4358: In July 2016, Massachusetts implemented a new ban on the sale of all semi-automatic rifles.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows Jay-Z and Beyonce holding their twin babies in June 2017.
# ----------------------------------------------------------------------------------------------------
# [Informal]  jay z and beyonce holding their twin babies in june 2017
#
# [Full Informal]  jay z and beyonce holding their twin babies in june 2017
# 4359: A photograph shows Jay-Z and Beyonce holding their twin babies in June 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  Facebook doesn't consider military emblems "appropriate" on their social network.
# ----------------------------------------------------------------------------------------------------
# [Informal]  FB does not find military emblems appropriate on there social network.
#
# [Full Informal]  FB does not find military emblems appropriate on there social network.
# 4360: Facebook doesn't consider military emblems "appropriate" on their social network.
# ----------------------------------------------------------------------------------------------------
# [Original]  A woman murdered her college roommate over too many Candy Crush requests.
# ----------------------------------------------------------------------------------------------------
# [Informal]  A female murdered her college roommate over a ton of candy crush requests.
#
# [Full Informal]  A female murdered her college roommate over a ton of candy crush requests.
# 4361: A woman murdered her college roommate over too many Candy Crush requests.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did a Wendy’s Employee Admit to “Pooping” in Chili for Over 2 Years?
# ----------------------------------------------------------------------------------------------------
# [Informal]  did a watsons employee admit to pooping in chili over 2 yrs?
#
# [Full Informal]  did a watsons employee admit to pooping in chili over 2 yrs?
# 4362: Did a Wendy’s Employee Admit to “Pooping” in Chili for Over 2 Years?
# ----------------------------------------------------------------------------------------------------
# [Original]  New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind of blood vessel in the hands and feet, ending the controversy over the disease’s cause and mechanism.
# ----------------------------------------------------------------------------------------------------
# [Informal]  new research proves that fibromyalgia is caused by multiple nerves in the hands and feet, breaking the mold on why this disease
#
# [Full Informal]  new research proves that fibromyalgia is caused by multiple nerves in the hands and feet, breaking the mold on why this disease
# 4363: New research has uncovered that the true cause of fibromyalgia is an excess number of specific nerves found near a specific kind of blood vessel in the hands and feet, ending the controversy over the disease’s cause and mechanism.
# ----------------------------------------------------------------------------------------------------
# [Original]  Hillary Clinton's popular vote win in the presidential election came entirely from the state of California.
# ----------------------------------------------------------------------------------------------------
# [Informal]  all the way from california was hilary clinton winning the presidential race
#
# [Full Informal]  all the way from california was hilary clinton winning the presidential race
# 4364: Hillary Clinton's popular vote win in the presidential election came entirely from the state of California.
# ----------------------------------------------------------------------------------------------------
# [Original]  Schools are removing analog clocks because students no longer know how to tell time.
# ----------------------------------------------------------------------------------------------------
# [Informal]  schools are pulling out analog clocks because students no longer know how to tell time.
#
# [Full Informal]  schools are pulling out analog clocks because students no longer know how to tell time.
# 4365: Schools are removing analog clocks because students no longer know how to tell time.
# ----------------------------------------------------------------------------------------------------
# [Original]  Hooters Restaurants are offering a special deal to customers who bring in photographs of their exes on Valentine's Day.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Hooters Restaurants will offer special deal to clients bringing in pictures of their ex for Vday
#
# [Full Informal]  Hooters Restaurants will offer special deal to clients bringing in pictures of their ex for Vday
# 4366: Hooters Restaurants are offering a special deal to customers who bring in photographs of their exes on Valentine's Day.
# ----------------------------------------------------------------------------------------------------
# [Original]  More attacks on U.S. embassies, with more people killed, occurred during the G.W. Bush and Reagan administrations than under Obama.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the attack on u.s. embassies killed a lot more during the bush,reagan administrations than under ob
#
# [Full Informal]  the attack on u.s. embassies killed a lot more during the bush,reagan administrations than under ob
# 4367: More attacks on U.S. embassies, with more people killed, occurred during the G.W. Bush and Reagan administrations than under Obama.
# ----------------------------------------------------------------------------------------------------
# [Original]  If you die, you can send your ashes to legislators as one final act of protest.
# ----------------------------------------------------------------------------------------------------
# [Informal]  and if you die you can send your ashes to legislators as one final step of protest.
#
# [Full Informal]  and if you die you can send your ashes to legislators as one final step of protest.
# 4368: If you die, you can send your ashes to legislators as one final act of protest.
# ----------------------------------------------------------------------------------------------------
# [Original]  A scientific study shows the death of Alfie Evans was caused by aluminum additives in vaccines.
# ----------------------------------------------------------------------------------------------------
# [Informal]  There's a study that says Alfie Evans died from the additives in the vaccine that cause that.
#
# [Full Informal]  There's a study that says Alfie Evans died from the additives in the vaccine that cause that.
# 4369: A scientific study shows the death of Alfie Evans was caused by aluminum additives in vaccines.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did President Nixon Say Watergate Details Were 'Illegally' Leaked by Deep Throat?
# ----------------------------------------------------------------------------------------------------
# [Informal]  Did Nixon say Watergate details were illegally leaked by Deep Throat?
#
# [Full Informal]  Did Nixon say Watergate details were illegally leaked by Deep Throat?
# 4370: Did President Nixon Say Watergate Details Were 'Illegally' Leaked by Deep Throat?
# ----------------------------------------------------------------------------------------------------
# [Original]  Fox News host Sean Hannity has died after a bicycling accident
# ----------------------------------------------------------------------------------------------------
# [Informal]  Sean Hannity died from a bike accident on Fox News
#
# [Full Informal]  Sean Hannity died from a bike accident on Fox News
# 4371: Fox News host Sean Hannity has died after a bicycling accident
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Jeff Sessions Say ‘If We Inflict Fear and Pain on Children, Adults Won’t Want to Come Here’?
# ----------------------------------------------------------------------------------------------------
# [Informal]  did jeff sebs say if we inflict fear and pain on kids, adults wont want to come here?
#
# [Full Informal]  did jeff sebs say if we inflict fear and pain on kids, adults wont want to come here?
# 4372: Did Jeff Sessions Say ‘If We Inflict Fear and Pain on Children, Adults Won’t Want to Come Here’?
# ----------------------------------------------------------------------------------------------------
# [Original]  Comedian Tommy Chong of 'Cheech and Chong' fame passed away in February 2017.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Comedian Tommy Chong of Cheech and Chong died in February 2017.
#
# [Full Informal]  Comedian Tommy Chong of Cheech and Chong died in February 2017.
# 4373: Comedian Tommy Chong of 'Cheech and Chong' fame passed away in February 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  Photographs show a New Jersey monument to the victims of 9/11 that was donated by Russia.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Russia donated a monument in New Jersey to victims of 9/11
#
# [Full Informal]  Russia donated a monument in New Jersey to victims of 9/11
# 4374: Photographs show a New Jersey monument to the victims of 9/11 that was donated by Russia.
# ----------------------------------------------------------------------------------------------------
# [Original]  Ivanka Trump said that she would "mace" her "father" during an appearance on a talk show.
# ----------------------------------------------------------------------------------------------------
# [Informal]  ivanka trump sat on a talk show and said she would "mace" her dad.
#
# [Full Informal]  ivanka trump sat on a talk show and said she would "mace" her dad.
# 4375: Ivanka Trump said that she would "mace" her "father" during an appearance on a talk show.
# ----------------------------------------------------------------------------------------------------
# [Original]  Nearly 5 million uncounted California ballots cast for Bernie Sanders were found on Hillary Clinton's private email server by the F.B.I.
# ----------------------------------------------------------------------------------------------------
# [Informal]  F.B.I. found nearly 5 million California ballots for Bernie Sanders on Hillary Clinton's private email server.
#
# [Full Informal]  F.B.I. found nearly 5 million California ballots for Bernie Sanders on Hillary Clinton's private email server.
# 4376: Nearly 5 million uncounted California ballots cast for Bernie Sanders were found on Hillary Clinton's private email server by the F.B.I.
# ----------------------------------------------------------------------------------------------------
# [Original]  Coiled mattresses cause cancer by amplifying radio waves.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Coiled mattresses cause cancer by amplifying radio waves
#
# [Full Informal]  Coiled mattresses cause cancer by amplifying radio waves
# 4377: Coiled mattresses cause cancer by amplifying radio waves.
# ----------------------------------------------------------------------------------------------------
# [Original]  A set of photographs accurately depict the number of New England Patriots players in attendance at a White House ceremony in 2015 and 2017.
# ----------------------------------------------------------------------------------------------------
# [Informal]  photos accurately depicts the number of New England Patriots players in attendance at a White House ceremony in 2015 and 2017.
#
# [Full Informal]  photos accurately depicts the number of New England Patriots players in attendance at a White House ceremony in 2015 and 2017.
# 4378: A set of photographs accurately depict the number of New England Patriots players in attendance at a White House ceremony in 2015 and 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  Morgue Employee Cremated by Mistake While Taking a Nap?
# ----------------------------------------------------------------------------------------------------
# [Informal]  morgue employee cremated by mistake while taking nap???
#
# [Full Informal]  morgue employee cremated by mistake while taking nap???
# 4379: Morgue Employee Cremated by Mistake While Taking a Nap?
# ----------------------------------------------------------------------------------------------------
# [Original]  An image shows a "Georgian Speekle," one of the world's scariest insects.
# ----------------------------------------------------------------------------------------------------
# [Informal]  A photo of a Georgian Speekle, one of the world's scariest insects
#
# [Full Informal]  A photo of a Georgian Speekle, one of the world's scariest insects
# 4380: An image shows a "Georgian Speekle," one of the world's scariest insects.
# ----------------------------------------------------------------------------------------------------
# [Original]  The NFL is banning the playing of the U.S. national anthem beginning in 2017.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the NFL is banning the U.S. national anthem starting in 2017
#
# [Full Informal]  the NFL is banning the U.S. national anthem starting in 2017
# 4381: The NFL is banning the playing of the U.S. national anthem beginning in 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  We investigate an assortment of claims about the 2017 tax bill and its provisions.
# ----------------------------------------------------------------------------------------------------
# [Informal]  we look into a variety of claims about the 2017 tax bill and its provisions.
#
# [Full Informal]  we look into a variety of claims about the 2017 tax bill and its provisions.
# 4382: We investigate an assortment of claims about the 2017 tax bill and its provisions.
# ----------------------------------------------------------------------------------------------------
# [Original]  Lebron James Wore a Protest Shirt?
# ----------------------------------------------------------------------------------------------------
# [Informal]  lebron james wore a protest tshirt?
#
# [Full Informal]  lebron james wore a protest tshirt?
# 4383: Lebron James Wore a Protest Shirt?
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Papa John's Withdraw Their NFL Advertising?
# ----------------------------------------------------------------------------------------------------
# [Informal]  Papa John's pulled NFL TV ads?
#
# [Full Informal]  Papa John's pulled NFL TV ads?
# 4384: Did Papa John's Withdraw Their NFL Advertising?
# ----------------------------------------------------------------------------------------------------
# [Original]  Will Entering Your PIN in Reverse at an ATM Summon the Police?
# ----------------------------------------------------------------------------------------------------
# [Informal]  will putting your pn in reverse at an aatm alarm the cops?
#
# [Full Informal]  will putting your pn in reverse at an aatm alarm the cops?
# 4385: Will Entering Your PIN in Reverse at an ATM Summon the Police?
# ----------------------------------------------------------------------------------------------------
# [Original]  Hillary Clinton cancelled a campaign event because of "bizarre eye movements."
# ----------------------------------------------------------------------------------------------------
# [Informal]  hilary clinton cancelled a campaign event because of freak eye movements.
#
# [Full Informal]  hilary clinton cancelled a campaign event because of freak eye movements.
# 4386: Hillary Clinton cancelled a campaign event because of "bizarre eye movements."
# ----------------------------------------------------------------------------------------------------
# [Original]  Video features a North Korean propaganda report on 'how Americans live today.'
# ----------------------------------------------------------------------------------------------------
# [Informal]  video containing a northkorean propaganda report on how 'us americans live today.'
#
# [Full Informal]  video containing a northkorean propaganda report on how 'us americans live today.'
# 4387: Video features a North Korean propaganda report on 'how Americans live today.'
# ----------------------------------------------------------------------------------------------------
# [Original]  The United States has the third-highest rate of homicides worldwide, but drops dramatically in the rankings if four major cities are excluded from the stats.
# ----------------------------------------------------------------------------------------------------
# [Informal]  US homicides are the 3rd highest in the world, it drops drastically if you take four major cities out.
#
# [Full Informal]  US homicides are the 3rd highest in the world, it drops drastically if you take four major cities out.
# 4388: The United States has the third-highest rate of homicides worldwide, but drops dramatically in the rankings if four major cities are excluded from the stats.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did a Tennessee Hardware Store Put Up a ‘No Gays Allowed’ Sign?
# ----------------------------------------------------------------------------------------------------
# [Informal]  Is the Tennessee Hardware Store Placing up a No Gays Allowed sign?
#
# [Full Informal]  Is the Tennessee Hardware Store Placing up a No Gays Allowed sign?
# 4389: Did a Tennessee Hardware Store Put Up a ‘No Gays Allowed’ Sign?
# ----------------------------------------------------------------------------------------------------
# [Original]  Actor Harry Shearer announced in November 2017 that he was leaving 'The Simpsons.'
# ----------------------------------------------------------------------------------------------------
# [Informal]  Harry Shearer left the Simpsons in November 2017.
#
# [Full Informal]  Harry Shearer left the Simpsons in November 2017.
# 4390: Actor Harry Shearer announced in November 2017 that he was leaving 'The Simpsons.'
# ----------------------------------------------------------------------------------------------------
# [Original]  The U.S. federal government is enacting a nationwide minimum hunting age of twenty-one (or eighteen).
# ----------------------------------------------------------------------------------------------------
# [Informal]  the federal government enacts a nationwide minimum hunting age of 21 or 18
#
# [Full Informal]  the federal government enacts a nationwide minimum hunting age of 21 or 18
# 4391: The U.S. federal government is enacting a nationwide minimum hunting age of twenty-one (or eighteen).
# ----------------------------------------------------------------------------------------------------
# [Original]  Does This Trump-Loving Celebrity Want Critics to Move Out of the United States?
# ----------------------------------------------------------------------------------------------------
# [Informal]  Does this boo lovin' tycoon want critics to move out of the US?
#
# [Full Informal]  Does this boo lovin' tycoon want critics to move out of the US?
# 4392: Does This Trump-Loving Celebrity Want Critics to Move Out of the United States?
# ----------------------------------------------------------------------------------------------------
# [Original]  Rihanna's Instagram message to followers to throw away the Snapchat app caused the company's share value to fall by hundreds of millions of dollars in one day.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Rihanna's Instagram message to followers to dump Snapchat got the company's shares down hundreds of millions in one day
#
# [Full Informal]  Rihanna's Instagram message to followers to dump Snapchat got the company's shares down hundreds of millions in one day
# 4393: Rihanna's Instagram message to followers to throw away the Snapchat app caused the company's share value to fall by hundreds of millions of dollars in one day.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows President Trump making a "fist-pumping" hand gesture at a memorial for 9/11 victims.
# ----------------------------------------------------------------------------------------------------
# [Informal]  President Trump's hand gesture 'fist spumping' at a 9/11 memorial.
#
# [Full Informal]  President Trump's hand gesture 'fist spumping' at a 9/11 memorial.
# 4394: A photograph shows President Trump making a "fist-pumping" hand gesture at a memorial for 9/11 victims.
# ----------------------------------------------------------------------------------------------------
# [Original]  Brian Kelley and Tyler Hubbard from the band Florida Georgia Line have announced that they are getting married.
# ----------------------------------------------------------------------------------------------------
# [Informal]  brian kelley and tyler hubbard of florida georgia line announce they are getting married
#
# [Full Informal]  brian kelley and tyler hubbard of florida georgia line announce they are getting married
# 4395: Brian Kelley and Tyler Hubbard from the band Florida Georgia Line have announced that they are getting married.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Customs Agents Board a Bus in Florida Asking for Proof of Citizenship?
# ----------------------------------------------------------------------------------------------------
# [Informal]  Did Customs agents board a bus in Florida asking for proof of citizenship?
#
# [Full Informal]  Did Customs agents board a bus in Florida asking for proof of citizenship?
# 4396: Did Customs Agents Board a Bus in Florida Asking for Proof of Citizenship?
# ----------------------------------------------------------------------------------------------------
# [Original]  Donald Trump called Abraham Lincoln a traitor.
# ----------------------------------------------------------------------------------------------------
# [Informal]  abraham lindsay is called a traitor by donald trump.
#
# [Full Informal]  abraham lindsay is called a traitor by donald trump.
# 4397: Donald Trump called Abraham Lincoln a traitor.
# ----------------------------------------------------------------------------------------------------
# [Original]  A CDC doctor who swarned the public that flu shots had caused a "deadly flu epidemic" was found dead:
# ----------------------------------------------------------------------------------------------------
# [Informal]  a cdc doctor who warned people that there was a dead flu epidemic was found dead
#
# [Full Informal]  a cdc doctor who warned people that there was a dead flu epidemic was found dead
# 4398: A CDC doctor who swarned the public that flu shots had caused a "deadly flu epidemic" was found dead:
# ----------------------------------------------------------------------------------------------------
# [Original]  Warren Buffett quipped that he could end the deficit by passing "a law that says anytime there is a deficit of more than 3% of GDP, all sitting members of Congress are ineligible for re-election.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Warren Buffett said that he could get rid of the deficit by passing a law that said whenever there is a deficit over 3% of GDP
#
# [Full Informal]  Warren Buffett said that he could get rid of the deficit by passing a law that said whenever there is a deficit over 3% of GDP
# 4399: Warren Buffett quipped that he could end the deficit by passing "a law that says anytime there is a deficit of more than 3% of GDP, all sitting members of Congress are ineligible for re-election.
# ----------------------------------------------------------------------------------------------------
# [Original]  Was White Supremacist Who Killed Protester a Democrat Who Visited Obama in Oval Office?
# ----------------------------------------------------------------------------------------------------
# [Informal]  was white supremacist who killed protester a democrat who visited barack obama in oval office?
#
# [Full Informal]  was white supremacist who killed protester a democrat who visited barack obama in oval office?
# 4400: Was White Supremacist Who Killed Protester a Democrat Who Visited Obama in Oval Office?
# ----------------------------------------------------------------------------------------------------
# [Original]  WikiLeaks documents revealed campaign head John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect.
# ----------------------------------------------------------------------------------------------------
# [Informal]  wikileaks revealed that campaign head john podesta slammed hilary c.
#
# [Full Informal]  wikileaks revealed that campaign head john podesta slammed hilary c.
# 4401: WikiLeaks documents revealed campaign head John Podesta unflatteringly described Hillary Clinton's personal hygiene and intellect.
# ----------------------------------------------------------------------------------------------------
# [Original]  Covfefe means something, anything.
# ----------------------------------------------------------------------------------------------------
# [Informal]  covfefe means somethinganything.
#
# [Full Informal]  covfefe means somethinganything.
# 4402: Covfefe means something, anything.
# ----------------------------------------------------------------------------------------------------
# [Original]  An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
# ----------------------------------------------------------------------------------------------------
# [Informal]  police officer in atlanta kills baby after arguing over breastfeeding with the baby's mama
#
# [Full Informal]  police officer in atlanta kills baby after arguing over breastfeeding with the baby's mama
# 4403: An Atlanta police officer killed a baby following a breastfeeding dispute with the child's mother.
# ----------------------------------------------------------------------------------------------------
# [Original]  A loon appears on Canada's one-dollar coin because the original dies, featuring a different design, were lost in transit.
# ----------------------------------------------------------------------------------------------------
# [Informal]  loon on a canadian one dollar coin because they lost the original dies that look a bit different.
#
# [Full Informal]  loon on a canadian one dollar coin because they lost the original dies that look a bit different.
# 4404: A loon appears on Canada's one-dollar coin because the original dies, featuring a different design, were lost in transit.
# ----------------------------------------------------------------------------------------------------
# [Original]  Did Fox News Use an Image of Patti LaBelle During Their Aretha Franklin Tribute?
# ----------------------------------------------------------------------------------------------------
# [Informal]  did fox news use a pic of patti la belle to honor aretha franklin?
#
# [Full Informal]  did fox news use a pic of patti la belle to honor aretha franklin?
# 4405: Did Fox News Use an Image of Patti LaBelle During Their Aretha Franklin Tribute?
# ----------------------------------------------------------------------------------------------------
# [Original]  The US government cancelled all 4th of July fireworks due to terror fears.
# ----------------------------------------------------------------------------------------------------
# [Informal]  4th of July all fireworks cancelled in the us for terror fears.
#
# [Full Informal]  4th of July all fireworks cancelled in the us for terror fears.
# 4406: The US government cancelled all 4th of July fireworks due to terror fears.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Obama issued an order banning U.S. military personnel from using the word "Christmas."
# ----------------------------------------------------------------------------------------------------
# [Informal]  The president ordered that U.S. military personnel can't use the word "Christmas".
#
# [Full Informal]  The president ordered that U.S. military personnel can't use the word "Christmas".
# 4407: President Obama issued an order banning U.S. military personnel from using the word "Christmas."
# ----------------------------------------------------------------------------------------------------
# [Original]  Tiny Hand Sir
# ----------------------------------------------------------------------------------------------------
# [Informal]  little hand sir
#
# [Full Informal]  little hand sir
# 4408: Tiny Hand Sir
# ----------------------------------------------------------------------------------------------------
# [Original]  A local identification card program in Chicago would allow undocumented immigrants to vote in United States elections.
# ----------------------------------------------------------------------------------------------------
# [Informal]  In Chicago a local ID program could allow undocumented immigrants to vote in US elections
#
# [Full Informal]  In Chicago a local ID program could allow undocumented immigrants to vote in US elections
# 4409: A local identification card program in Chicago would allow undocumented immigrants to vote in United States elections.
# ----------------------------------------------------------------------------------------------------
# [Original]  Placing a coin on top of a frozen glass of water in your freezer can help you tell if your freezer experienced a significant loss of power in your absence.
# ----------------------------------------------------------------------------------------------------
# [Informal]  a coin on top of a frozen glass of water helps you if your freezer experienced a major power loss in your absence.
#
# [Full Informal]  a coin on top of a frozen glass of water helps you if your freezer experienced a major power loss in your absence.
# 4410: Placing a coin on top of a frozen glass of water in your freezer can help you tell if your freezer experienced a significant loss of power in your absence.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Trump has ordered the construction of concentration camps in the U.S.
# ----------------------------------------------------------------------------------------------------
# [Informal]  president trump has ordered the construction of concentration camps in the U.S.
#
# [Full Informal]  president trump has ordered the construction of concentration camps in the U.S.
# 4411: President Trump has ordered the construction of concentration camps in the U.S.
# ----------------------------------------------------------------------------------------------------
# [Original]  The federal government passed a law permitting police officers to shoot dogs if they bark or move.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the federal government passed law that permits cops to shoot dogs if they bark or move.
#
# [Full Informal]  the federal government passed law that permits cops to shoot dogs if they bark or move.
# 4412: The federal government passed a law permitting police officers to shoot dogs if they bark or move.
# ----------------------------------------------------------------------------------------------------
# [Original]  Breast milk is glittery gold under a microscope.
# ----------------------------------------------------------------------------------------------------
# [Informal]  breast milk glitters gold under a microscope
#
# [Full Informal]  breast milk glitters gold under a microscope
# 4413: Breast milk is glittery gold under a microscope.
# ----------------------------------------------------------------------------------------------------
# [Original]  Penguins fall over onto their backs while trying to observe airplanes flying overhead.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Penguins fall on their backs trying to see aircraft flying overhead.
#
# [Full Informal]  Penguins fall on their backs trying to see aircraft flying overhead.
# 4414: Penguins fall over onto their backs while trying to observe airplanes flying overhead.
# ----------------------------------------------------------------------------------------------------
# [Original]  Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out to Al Gore.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out
#
# [Full Informal]  Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out
# 4415: Irena Sendler, credited with saving 2,500 Polish Jews from the Holocaust, was a candidate for the 2007 Nobel Peace Prize but lost out to Al Gore.
# ----------------------------------------------------------------------------------------------------
# [Original]  Actor Robert De Niro blasted Donald Trump in a video meant to encourage people to vote.
# ----------------------------------------------------------------------------------------------------
# [Informal]  robert de niro blasts donald trump in a video to get people to vote.
#
# [Full Informal]  robert de niro blasts donald trump in a video to get people to vote.
# 4416: Actor Robert De Niro blasted Donald Trump in a video meant to encourage people to vote.
# ----------------------------------------------------------------------------------------------------
# [Original]  Radiation from the 2011 Fukushima nuclear disaster has caused 100% infant mortality among orca whales.
# ----------------------------------------------------------------------------------------------------
# [Informal]  radiance from 2011 fukushima nuclear disaster has caused 100% infant mortality among orca whales.
#
# [Full Informal]  radiance from 2011 fukushima nuclear disaster has caused 100% infant mortality among orca whales.
# 4417: Radiation from the 2011 Fukushima nuclear disaster has caused 100% infant mortality among orca whales.
# ----------------------------------------------------------------------------------------------------
# [Original]  Fire and smoke billowing from the vicinity of the Eiffel Tower were evidence of a Bastille Day terrorist attack in Paris.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the fire and smoke near the Eiffel Tower indicates a terrorist attack in paris on Bastille day
#
# [Full Informal]  the fire and smoke near the Eiffel Tower indicates a terrorist attack in paris on Bastille day
# 4418: Fire and smoke billowing from the vicinity of the Eiffel Tower were evidence of a Bastille Day terrorist attack in Paris.
# ----------------------------------------------------------------------------------------------------
# [Original]  ISIS members are operating a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
# ----------------------------------------------------------------------------------------------------
# [Informal]  ISIS's operations a camp near el paso, trying to cross the mexican border, has been busted
#
# [Full Informal]  ISIS's operations a camp near el paso, trying to cross the mexican border, has been busted
# 4419: ISIS members are operating a camp near El Paso and have been arrested trying to cross the U.S.-Mexico border.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows Barack Obama holding a t-shirt bearing the slogan "Michelle Obama 2020."
# ----------------------------------------------------------------------------------------------------
# [Informal]  Barack Obama with a tshirt that reads Michelle Obama 2020 on it
#
# [Full Informal]  Barack Obama with a tshirt that reads Michelle Obama 2020 on it
# 4420: A photograph shows Barack Obama holding a t-shirt bearing the slogan "Michelle Obama 2020."
# ----------------------------------------------------------------------------------------------------
# [Original]  Earth's magnetosphere collapsed for two hours on 23 April 2016.
# ----------------------------------------------------------------------------------------------------
# [Informal]  earth's magnetosphere collapsed for two hours 23 april 2016
#
# [Full Informal]  earth's magnetosphere collapsed for two hours 23 april 2016
# 4421: Earth's magnetosphere collapsed for two hours on 23 April 2016.
# ----------------------------------------------------------------------------------------------------
# [Original]  The purpose of the 'crash' or 'brace' position in airliners is to kill passengers quickly in the event of an crash, or to preserve their remains so as to make identification of bodies easier.
# ----------------------------------------------------------------------------------------------------
# [Informal]  crash brace is to kill people in a crash... or preserve remains...to make ident
#
# [Full Informal]  crash brace is to kill people in a crash... or preserve remains...to make ident
# 4422: The purpose of the 'crash' or 'brace' position in airliners is to kill passengers quickly in the event of an crash, or to preserve their remains so as to make identification of bodies easier.
# ----------------------------------------------------------------------------------------------------
# [Original]  Snapchat, a popular messaging service, announced in November 2017 that it is being closed down by the end of the year.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Snapchat is a popular messaging service and said it would close in the end of the year in November 2017.
#
# [Full Informal]  Snapchat is a popular messaging service and said it would close in the end of the year in November 2017.
# 4423: Snapchat, a popular messaging service, announced in November 2017 that it is being closed down by the end of the year.
# ----------------------------------------------------------------------------------------------------
# [Original]  This Halloween has been designated as "National Kill a Pitbull Day."
# ----------------------------------------------------------------------------------------------------
# [Informal]  this hooghday is National Kill a Pitbull day
#
# [Full Informal]  this hooghday is National Kill a Pitbull day
# 4424: This Halloween has been designated as "National Kill a Pitbull Day."
# ----------------------------------------------------------------------------------------------------
# [Original]  Canadian prime minister Justin Trudeau announced a new law to arrest and fine anyone wearing clown costumes.
# ----------------------------------------------------------------------------------------------------
# [Informal]  The prime minister of Canada Justin Trudeau announced a new law arresting and fineing clowns.
#
# [Full Informal]  The prime minister of Canada Justin Trudeau announced a new law arresting and fineing clowns.
# 4425: Canadian prime minister Justin Trudeau announced a new law to arrest and fine anyone wearing clown costumes.
# ----------------------------------------------------------------------------------------------------
# [Original]  A gang member died after trying to gold plate his genitals.
# ----------------------------------------------------------------------------------------------------
# [Informal]  So, a guy got killed trying to gold plate his genitals...
#
# [Full Informal]  So, a guy got killed trying to gold plate his genitals...
# 4426: A gang member died after trying to gold plate his genitals.
# ----------------------------------------------------------------------------------------------------
# [Original]  A judge told an atheist plaintiff who challenged religious holidays that atheists already have their own holiday: April 1.
# ----------------------------------------------------------------------------------------------------
# [Informal]  a judge told a atheist plaintiff who challenged religious holidays that atheists already have their own holiday, April 1.
#
# [Full Informal]  a judge told a atheist plaintiff who challenged religious holidays that atheists already have their own holiday, April 1.
# 4427: A judge told an atheist plaintiff who challenged religious holidays that atheists already have their own holiday: April 1.
# ----------------------------------------------------------------------------------------------------
# [Original]  Both Robert E. Lee and Jefferson Davis disavowed the Confederacy after the Civil War.
# ----------------------------------------------------------------------------------------------------
# [Informal]  robert e. lee and jefferson david rejected the confederacy after the civil war.
#
# [Full Informal]  robert e. lee and jefferson david rejected the confederacy after the civil war.
# 4428: Both Robert E. Lee and Jefferson Davis disavowed the Confederacy after the Civil War.
# ----------------------------------------------------------------------------------------------------
# [Original]  Musicians Robert Plant and Cher plan to wed at Westminster Abbey in July 2016.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Musicians Robert Plant and Cher are planning on getting married at Westminster Abbey in july 2016.
#
# [Full Informal]  Musicians Robert Plant and Cher are planning on getting married at Westminster Abbey in july 2016.
# 4429: Musicians Robert Plant and Cher plan to wed at Westminster Abbey in July 2016.
# ----------------------------------------------------------------------------------------------------
# [Original]  American Sniper subject Chris Kyle shot dozens of looters after Hurricane Katrina, killed two attempted carjackers, and punched Jesse Ventura in the face.
# ----------------------------------------------------------------------------------------------------
# [Informal]  american sniper subject,chris kyle shot dozens of looters after hurricane katrina, killed two
#
# [Full Informal]  american sniper subject,chris kyle shot dozens of looters after hurricane katrina, killed two
# 4430: American Sniper subject Chris Kyle shot dozens of looters after Hurricane Katrina, killed two attempted carjackers, and punched Jesse Ventura in the face.
# ----------------------------------------------------------------------------------------------------
# [Original]  Donald Trump encouraged supporters to engage in a Nazi-style salute at a campaign rally.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Donald Trump pushed supporters to perform a nazi salute at a rally.
#
# [Full Informal]  Donald Trump pushed supporters to perform a nazi salute at a rally.
# 4431: Donald Trump encouraged supporters to engage in a Nazi-style salute at a campaign rally.
# ----------------------------------------------------------------------------------------------------
# [Original]  Marijuana cigarettes deposit four times more tar into smokers' lungs than tobacco-based cigarettes.
# ----------------------------------------------------------------------------------------------------
# [Informal]  marijuana cigarettes put 4 times more tar in smokers lungs than tobacco based cigarettes do.
#
# [Full Informal]  marijuana cigarettes put 4 times more tar in smokers lungs than tobacco based cigarettes do.
# 4432: Marijuana cigarettes deposit four times more tar into smokers' lungs than tobacco-based cigarettes.
# ----------------------------------------------------------------------------------------------------
# [Original]  Can This Machine Automatically Sort Balls by Color?
# ----------------------------------------------------------------------------------------------------
# [Informal]  this machine auto sort balls by color???
#
# [Full Informal]  this machine auto sort balls by color???
# 4433: Can This Machine Automatically Sort Balls by Color?
# ----------------------------------------------------------------------------------------------------
# [Original]  WhatsApp will share personal user information with Facebook, who will make it publicly available.
# ----------------------------------------------------------------------------------------------------
# [Informal]  WhatsApp will share pc info to facebook who will make it public.
#
# [Full Informal]  WhatsApp will share pc info to facebook who will make it public.
# 4434: WhatsApp will share personal user information with Facebook, who will make it publicly available.
# ----------------------------------------------------------------------------------------------------
# [Original]  In 1974, Bill Clinton said President Richard Nixon should resign for lying to government officials.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Bill Clinton in 1974, said Richard Nixon should resign because he lied to goverment officials.
#
# [Full Informal]  Bill Clinton in 1974, said Richard Nixon should resign because he lied to goverment officials.
# 4435: In 1974, Bill Clinton said President Richard Nixon should resign for lying to government officials.
# ...
#
# [Full Informal]  Sophia, a robot just got citizenship, was killed by an angry mob in Saudi Arabia
# 5044: An angry mob in Saudi Arabia beheaded "Sophia," a robot recently awarded citizenship.
# ----------------------------------------------------------------------------------------------------
# [Original]  A woman claimed she became pregnant from viewing a 3D porn film.
# ----------------------------------------------------------------------------------------------------
# [Informal]  One woman said she became pregnant watching a 3d porn movie.
#
# [Full Informal]  One woman said she became pregnant watching a 3d porn movie.
# 5045: A woman claimed she became pregnant from viewing a 3D porn film.
# ----------------------------------------------------------------------------------------------------
# [Original]  The 'Dell Dude' commercials ended because pitchman Benjamin Curtis was arrested for marijuana possession.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the 'Dell Dude' commercials ended because pitchman Benjamin Curtis was arrested for pot possession.
#
# [Full Informal]  the 'Dell Dude' commercials ended because pitchman Benjamin Curtis was arrested for pot possession.
# 5046: The 'Dell Dude' commercials ended because pitchman Benjamin Curtis was arrested for marijuana possession.
# ----------------------------------------------------------------------------------------------------
# [Original]  A massive recall of chicken nuggets is underway after authorities in Iowa found human remains in a meat processing facility.
# ----------------------------------------------------------------------------------------------------
# [Informal]  an Iowa coop found bones in a meat processing facility, a massive recall of chicken nuggets is underway
#
# [Full Informal]  an Iowa coop found bones in a meat processing facility, a massive recall of chicken nuggets is underway
# 5047: A massive recall of chicken nuggets is underway after authorities in Iowa found human remains in a meat processing facility.
# ----------------------------------------------------------------------------------------------------
# [Original]  Patients can circumvent insurance company claim denials by requesting a specific form of documentation, as the insurance company will opt to simply cover the cost rather than provide the paperwork.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Patients can avoid denials by asking for a specific form of documentation, the insurance company will just cover the cost rather than provide the paperwork.
#
# [Full Informal]  Patients can avoid denials by asking for a specific form of documentation, the insurance company will just cover the cost rather than provide the paperwork.
# 5048: Patients can circumvent insurance company claim denials by requesting a specific form of documentation, as the insurance company will opt to simply cover the cost rather than provide the paperwork.
# ----------------------------------------------------------------------------------------------------
# [Original]  Ted Cruz said that there was 'no place for gays in my America.'
# ----------------------------------------------------------------------------------------------------
# [Informal]  TED CRUZ said that there was no place for gays in my America
#
# [Full Informal]  TED CRUZ said that there was no place for gays in my America
# 5049: Ted Cruz said that there was 'no place for gays in my America.'
# ----------------------------------------------------------------------------------------------------
# [Original]  The Chili's restaurant chain donates 15 percent of every sale to Planned Parenthood.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Chilis donates 15% of their sale to Planned Parenthood
#
# [Full Informal]  Chilis donates 15% of their sale to Planned Parenthood
# 5050: The Chili's restaurant chain donates 15 percent of every sale to Planned Parenthood.
# ----------------------------------------------------------------------------------------------------
# [Original]  The Women's March on Washington is tallying attendees by asking them to text "COUNT ME" to 89800.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Women's March on Washington tells attendees to text count me 89800.
#
# [Full Informal]  Women's March on Washington tells attendees to text count me 89800.
# 5051: The Women's March on Washington is tallying attendees by asking them to text "COUNT ME" to 89800.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Trump said police and firefighters make too much money in order to justify eliminating some of their tax deductions.
# ----------------------------------------------------------------------------------------------------
# [Informal]  ... President Trump said police and firefighters make too much money to justify eliminating some of their tax deductions.
#
# [Full Informal]  ... President Trump said police and firefighters make too much money to justify eliminating some of their tax deductions.
# 5052: President Trump said police and firefighters make too much money in order to justify eliminating some of their tax deductions.
# ----------------------------------------------------------------------------------------------------
# [Original]  The Book of Revelation describes the anti-Christ as someone with characteristics matching those of Barack Obama.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the antichrist is named in the Revelation Book
#
# [Full Informal]  the antichrist is named in the Revelation Book
# 5053: The Book of Revelation describes the anti-Christ as someone with characteristics matching those of Barack Obama.
# ----------------------------------------------------------------------------------------------------
# [Original]  Photograph shows a 9/11-themed shirt sold in the Middle East.
# ----------------------------------------------------------------------------------------------------
# [Informal]  photo shows a 9/11 themed shirt sold in the middle east.
#
# [Full Informal]  photo shows a 9/11 themed shirt sold in the middle east.
# 5054: Photograph shows a 9/11-themed shirt sold in the Middle East.
# ----------------------------------------------------------------------------------------------------
# [Original]  A photo shows an endangered fennec hare.
# ----------------------------------------------------------------------------------------------------
# [Informal]  a picture of an endangered fennec hare.
#
# [Full Informal]  a picture of an endangered fennec hare.
# 5055: A photo shows an endangered fennec hare.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Obama has announced he'll refuse to leave office if Donald Trump is elected President.
# ----------------------------------------------------------------------------------------------------
# [Informal]  PRESIDENT OBAY HAS SAYNED HE'LL DON'T LET OFF IF DONALD TRUMP
#
# [Full Informal]  PRESIDENT OBAY HAS SAYNED HE'LL DON'T LET OFF IF DONALD TRUMP
# 5056: President Obama has announced he'll refuse to leave office if Donald Trump is elected President.
# ----------------------------------------------------------------------------------------------------
# [Original]  Roy Moore accuser Beverly Young Nelson "forged" Moore's signature and inscription in her high school yearbook.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Roy Moore accuser Beverly Young Nelson "Fake" Moore's signature and inscription in her high school yearbook.
#
# [Full Informal]  Roy Moore accuser Beverly Young Nelson "Fake" Moore's signature and inscription in her high school yearbook.
# 5057: Roy Moore accuser Beverly Young Nelson "forged" Moore's signature and inscription in her high school yearbook.
# ----------------------------------------------------------------------------------------------------
# [Original]  President Trump filed for re-election early, which means non-profits can't criticize him without losing their tax-exempt status.
# ----------------------------------------------------------------------------------------------------
# [Informal]  because he filed for reelection early, which means non-profits cant criticize him without losing their tax exempt status
#
# [Full Informal]  because he filed for reelection early, which means non-profits cant criticize him without losing their tax exempt status
# 5058: President Trump filed for re-election early, which means non-profits can't criticize him without losing their tax-exempt status.
# ----------------------------------------------------------------------------------------------------
# [Original]  Hillary Clinton was reported dead on 11 September 2016, but the news was subsequently covered up and she was replaced by a body double.
# ----------------------------------------------------------------------------------------------------
# [Informal]  hilary clinton died 11 sept 2016 but the news was not true and she was replaced by a body double.
#
# [Full Informal]  hilary clinton died 11 sept 2016 but the news was not true and she was replaced by a body double.
# 5059: Hillary Clinton was reported dead on 11 September 2016, but the news was subsequently covered up and she was replaced by a body double.
# ----------------------------------------------------------------------------------------------------
# [Original]  Musician Neko Case's Vermont farmhouse was badly damaged in a fire in September 2017.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Neko Case's Vermont farmhouse was seriously damaged in a fire in September 2017.
#
# [Full Informal]  Neko Case's Vermont farmhouse was seriously damaged in a fire in September 2017.
# 5060: Musician Neko Case's Vermont farmhouse was badly damaged in a fire in September 2017.
# ----------------------------------------------------------------------------------------------------
# [Original]  For the first time in history the North Atlantic is empty of cargo ships in-transit.
# ----------------------------------------------------------------------------------------------------
# [Informal]  the North Atlantic is empty of cargo ships in transit for the first time in history
#
# [Full Informal]  the North Atlantic is empty of cargo ships in transit for the first time in history
# 5061: For the first time in history the North Atlantic is empty of cargo ships in-transit.
# ----------------------------------------------------------------------------------------------------
# [Original]  A woman shot and killed her boyfriend after an April Fool's Day marriage proposal prank.
# ----------------------------------------------------------------------------------------------------
# [Informal]  a girl shot her boyfriend, killing him after a date proposal prank APRIL FOOLS DAY
#
# [Full Informal]  a girl shot her boyfriend, killing him after a date proposal prank APRIL FOOLS DAY
# 5062: A woman shot and killed her boyfriend after an April Fool's Day marriage proposal prank.
# ----------------------------------------------------------------------------------------------------
# [Original]  Melania Trump said that Native Americans upset about the Dakota Access Pipeline should "go back to India".
# ----------------------------------------------------------------------------------------------------
# [Informal]  melania trump tells indians to go back to india about the Dakota Access pipeline
#
# [Full Informal]  melania trump tells indians to go back to india about the Dakota Access pipeline
# 5063: Melania Trump said that Native Americans upset about the Dakota Access Pipeline should "go back to India".
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows a 'Welcome Sign' outside of Mingo Country warning visitors that its citizens were armed and would "kill you back."
# ----------------------------------------------------------------------------------------------------
# [Informal]  Welcome Sign out of Mingo Country telling visitors that its citizens were armed and will kill you back
#
# [Full Informal]  Welcome Sign out of Mingo Country telling visitors that its citizens were armed and will kill you back
# 5064: A photograph shows a 'Welcome Sign' outside of Mingo Country warning visitors that its citizens were armed and would "kill you back."
# ----------------------------------------------------------------------------------------------------
# [Original]  A photograph shows William Harley and Arthur Davidson unveiling their first motorcycle in 1914.
# ----------------------------------------------------------------------------------------------------
# [Informal]  William Harley and Arthur Davidson unveiled their first motorcycle in 1914.
#
# [Full Informal]  William Harley and Arthur Davidson unveiled their first motorcycle in 1914.
# 5065: A photograph shows William Harley and Arthur Davidson unveiling their first motorcycle in 1914.
# ----------------------------------------------------------------------------------------------------
# [Original]  Image depicts "attitude adjustment" and "smile therapy" forced upon American housewives in the 1930s institutionalized for "not taking care of themselves" and acting "depressed."
# ----------------------------------------------------------------------------------------------------
# [Informal]  image of attitude adduction and smile therapy forced upon american housewives in the 1930s institutionalized for "not taking care of themselves" and
#
# [Full Informal]  image of attitude adduction and smile therapy forced upon american housewives in the 1930s institutionalized for "not taking care of themselves" and
# 5066: Image depicts "attitude adjustment" and "smile therapy" forced upon American housewives in the 1930s institutionalized for "not taking care of themselves" and acting "depressed."
# ----------------------------------------------------------------------------------------------------
# [Original]  A cook attempted to poison George Washington by feeding him tomatoes.
# ----------------------------------------------------------------------------------------------------
# [Informal]  cook tried to poison george washington by feeding him tomatoes.
#
# [Full Informal]  cook tried to poison george washington by feeding him tomatoes.
# 5067: A cook attempted to poison George Washington by feeding him tomatoes.
# ----------------------------------------------------------------------------------------------------
# [Original]  Cavities are contagious, primarily between intimate partners or children and caregivers.
# ----------------------------------------------------------------------------------------------------
# [Informal]  Cavities spread a lot...it's usually between sex, or between little kids and their parents.
#
# [Full Informal]  Cavities spread a lot...it's usually between sex, or between little kids and their parents.
# 5068: Cavities are contagious, primarily between intimate partners or children and caregivers.
# ----------------------------------------------------------------------------------------------------
# [Original]  A vacationing couple staying in a foul-smelling motel room discovered a body hidden under their bed.
# ----------------------------------------------------------------------------------------------------
# [Informal]  A couple stayed in a dirty motel room and they found a dead body hiding under their bed.
#
# [Full Informal]  A couple stayed in a dirty motel room and they found a dead body hiding under their bed.
# 5069: A vacationing couple staying in a foul-smelling motel room discovered a body hidden under their bed.

# %%
df_snes.to_csv('/content/drive/MyDrive/Deep Learning NLP/paper/snes_informal.tsv', 
               sep='\t', header=False, index=False)

# %%
df_snes
# Out:
#          claimID  ...           entities
# 0     snes-04484  ...           ['None']
# 1     snes-03162  ...           ['None']
# 2     snes-05436  ...           ['None']
# 3     snes-02901  ...       ['Kentucky']
# 4     snes-03347  ...           ['None']
# ...          ...  ...                ...
# 5064  snes-04959  ...           ['None']
# 5065  snes-01599  ...  ['United_States']
# 5066  snes-02900  ...           ['None']
# 5067  snes-03298  ...           ['None']
# 5068  snes-01833  ...           ['None']
#
# [5069 rows x 13 columns]
